# %%
import sys
sys.path.append('C:\\Utveckling\\sharkpylib')
sys.path.append('C:\\Utveckling\\ctdpy')  #  

from ctdpy.core.session import Session
from ctdpy.core.utils import generate_filepaths, get_reversed_dictionary

import time
from pprint import pprint

# %%
###################        GET FILES        #################### 

# base_dir = '\\\\winfs-proj\\proj\\havgem\\EXPRAPP\\Exprap2020\\Svea_v16 april\\CTD\\data'
base_dir = 'C:\\Utveckling\\ctdpy\\ctdpy\\tests\\etc\\exprapp_april_2020'

# Note the time difference (~ x10) when loading data from fileserver (EXPRAPP) compared to reading from local disc..
files = generate_filepaths(base_dir,
                           # pattern_list=['.cnv', '.xlsx'],   # Both cnv- and metadata-files
                           endswith='.cnv',                    # Only cnv-files
                           # endswith='.txt',                  # Presumably CTD-standard format
                           only_from_dir=True,                 # we exclude search of files from folders under "base_dir"
                           )

# %%
###################        Create SESSION object        ###################

s = Session(filepaths=files,
            reader='smhi',
            # reader='ctd_stdfmt',
            )

# %%
###################        READ DELIVERY DATA, CNV, XLSX        ###################

start_time = time.time()

datasets = s.read()

print("Datasets loaded--%.3f sec" % (time.time() - start_time))
# Out:
# dataset cnv
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\exprapp_april_2020\SBE09_1387_20200414_1152_77_10_0336.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\exprapp_april_2020\SBE09_1387_20200414_1453_77_10_0337.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\exprapp_april_2020\SBE09_1387_20200414_1635_77_10_0338.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\exprapp_april_2020\SBE09_1387_20200414_1734_77_10_0339.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\exprapp_april_2020\SBE09_1387_20200414_1911_77_10_0340.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\exprapp_april_2020\SBE09_1387_20200414_2056_77_10_0341.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\exprapp_april_2020\SBE09_1387_20200415_0210_77_10_0342.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\exprapp_april_2020\SBE09_1387_20200415_0708_77_10_0343.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\exprapp_april_2020\SBE09_1387_20200415_1036_77_10_0344.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\exprapp_april_2020\SBE09_1387_20200415_1326_77_10_0345.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\exprapp_april_2020\SBE09_1387_20200415_2002_77_10_0346.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\exprapp_april_2020\SBE09_1387_20200416_0314_77_10_0347.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\exprapp_april_2020\SBE09_1387_20200416_0639_77_10_0348.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\exprapp_april_2020\SBE09_1387_20200416_1300_77_10_0349.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\exprapp_april_2020\SBE09_1387_20200416_1604_77_10_0350.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\exprapp_april_2020\SBE09_1387_20200416_1915_77_10_0351.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\exprapp_april_2020\SBE09_1387_20200417_0438_77_10_0352.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\exprapp_april_2020\SBE09_1387_20200417_1328_77_10_0353.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\exprapp_april_2020\SBE09_1387_20200417_1857_77_10_0354.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\exprapp_april_2020\SBE09_1387_20200418_0409_77_10_0355.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\exprapp_april_2020\SBE09_1387_20200418_0846_77_10_0356.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\exprapp_april_2020\SBE09_1387_20200418_1555_77_10_0357.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\exprapp_april_2020\SBE09_1387_20200418_2216_77_10_0358.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\exprapp_april_2020\SBE09_1387_20200419_0604_77_10_0359.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\exprapp_april_2020\SBE09_1387_20200419_0854_77_10_0360.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Datasets loaded--1.018 sec

# %%
print('Files loaded:')
pprint(list(datasets[0].keys()))
# Out:
# Files loaded:
# ['SBE09_1387_20200414_1152_77_10_0336.cnv',
#  'SBE09_1387_20200414_1453_77_10_0337.cnv',
#  'SBE09_1387_20200414_1635_77_10_0338.cnv',
#  'SBE09_1387_20200414_1734_77_10_0339.cnv',
#  'SBE09_1387_20200414_1911_77_10_0340.cnv',
#  'SBE09_1387_20200414_2056_77_10_0341.cnv',
#  'SBE09_1387_20200415_0210_77_10_0342.cnv',
#  'SBE09_1387_20200415_0708_77_10_0343.cnv',
#  'SBE09_1387_20200415_1036_77_10_0344.cnv',
#  'SBE09_1387_20200415_1326_77_10_0345.cnv',
#  'SBE09_1387_20200415_2002_77_10_0346.cnv',
#  'SBE09_1387_20200416_0314_77_10_0347.cnv',
#  'SBE09_1387_20200416_0639_77_10_0348.cnv',
#  'SBE09_1387_20200416_1300_77_10_0349.cnv',
#  'SBE09_1387_20200416_1604_77_10_0350.cnv',
#  'SBE09_1387_20200416_1915_77_10_0351.cnv',
#  'SBE09_1387_20200417_0438_77_10_0352.cnv',
#  'SBE09_1387_20200417_1328_77_10_0353.cnv',
#  'SBE09_1387_20200417_1857_77_10_0354.cnv',
#  'SBE09_1387_20200418_0409_77_10_0355.cnv',
#  'SBE09_1387_20200418_0846_77_10_0356.cnv',
#  'SBE09_1387_20200418_1555_77_10_0357.cnv',
#  'SBE09_1387_20200418_2216_77_10_0358.cnv',
#  'SBE09_1387_20200419_0604_77_10_0359.cnv',
#  'SBE09_1387_20200419_0854_77_10_0360.cnv']

# %%
#  ###################        WRITE METADATA TO TEMPLATE        ###################
start_time = time.time()

s.save_data(datasets[0],  # datasets are stored in a list of 2 (idx 0: data, idx 1: metadata). For this example we only have data
            writer='metadata_template')

print("Metadata file created--%.3f sec" % (time.time() - start_time))

# Metadata template is stored under /ctdpy/ctdpy/exports/
# Out:
# Metadata file created--0.902 sec
