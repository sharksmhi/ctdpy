# %%
import sys
sys.path.append('C:\\Utveckling\\sharkpylib')
sys.path.append('C:\\Utveckling\\ctdpy')  #  

from ctdpy.core.session import Session
from ctdpy.core.utils import generate_filepaths, get_reversed_dictionary

import time
from pprint import pprint

# %%
###################        GET FILES        #################### 

# base_dir = 'C:\\Utveckling\\ctdpy\\ctdpy\\tests\\etc\\exprapp_april_2020'
base_dir = 'C:\\Temp\\CTD_DV\\maj'

files = generate_filepaths(base_dir,
                           pattern_list=['.cnv', '.xlsx'],   # Both cnv- and metadata-files
                           # endswith='.cnv',                # Only cnv-files
                           # endswith='.txt',                # Presumably CTD-standard format
                           only_from_dir=False,              # False: We accept filesearch from folders within base_dir, True: We only accept filesearch base_dir, not from folders within base_dir
                           )

# %%
###################        Create SESSION object         ###################

start_time = time.time()

s = Session(filepaths=files,
            reader='smhi',
            # reader='ctd_stdfmt',
            )

print("Session--%.3f sec" % (time.time() - start_time))
# Out:
# Session--0.105 sec

# %%
###################        READ DELIVERY DATA, CNV, XLSX        ###################

start_time = time.time()

datasets = s.read()

print("Datasets loaded--%.3f sec" % (time.time() - start_time))
# Out:
# dataset cnv
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200508_0610_77_10_0383.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200508_1140_77_10_0384.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200508_1831_77_10_0385.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200508_2315_77_10_0386.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200509_0603_77_10_0387.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200509_1210_77_10_0388.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200509_1618_77_10_0389.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200509_2250_77_10_0390.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200510_0714_77_10_0391.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200510_1626_77_10_0392.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200510_2017_77_10_0393.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200511_0256_77_10_0394.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200511_0709_77_10_0395.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200511_1541_77_10_0396.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200511_2143_77_10_0397.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200512_0036_77_10_0398.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200512_0403_77_10_0399.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200512_1150_77_10_0400.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200512_1527_77_10_0401.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200512_1812_77_10_0402.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200512_1922_77_10_0403.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200512_2028_77_10_0404.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200512_2207_77_10_0405.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200513_0002_77_10_0406.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200513_1111_77_10_0407.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200514_0450_77_10_0408.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200514_1153_77_10_0409.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200514_1501_77_10_0410.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# Loading text file: C:\Temp\CTD_DV\maj\SBE09_1387_20200514_2234_77_10_0411.cnv
# No mapping found for key: sbeox0V: Oxygen raw, SBE 43 [V]
# No mapping found for key: sbeox1V: Oxygen raw, SBE 43, 2 [V]
# No mapping found for key: secS-priS: Salinity, Practical, Difference, 2 - 1 [PSU]
# No mapping found for key: depSM: Depth [salt water, m], lat
# No mapping found for key: sbeox0PS: Oxygen, SBE 43 [% saturation], WS
# No mapping found for key: sbeox1PS: Oxygen, SBE 43, 2 [% saturation], WS
# dataset xlsx
#
#
# EXCEL-filenames
#
#
# Datasets loaded--1.260 sec

# %%
print('Files loaded:')
pprint(list(datasets[1].keys()))  # if intexerror, the metadata template has not been loaded: Check setup of file-generator
pprint(list(datasets[0].keys()))
# Out:
# Files loaded:
# ['ctd_metadata_maj.xlsx']
# ['SBE09_1387_20200508_0610_77_10_0383.cnv',
#  'SBE09_1387_20200508_1140_77_10_0384.cnv',
#  'SBE09_1387_20200508_1831_77_10_0385.cnv',
#  'SBE09_1387_20200508_2315_77_10_0386.cnv',
#  'SBE09_1387_20200509_0603_77_10_0387.cnv',
#  'SBE09_1387_20200509_1210_77_10_0388.cnv',
#  'SBE09_1387_20200509_1618_77_10_0389.cnv',
#  'SBE09_1387_20200509_2250_77_10_0390.cnv',
#  'SBE09_1387_20200510_0714_77_10_0391.cnv',
#  'SBE09_1387_20200510_1626_77_10_0392.cnv',
#  'SBE09_1387_20200510_2017_77_10_0393.cnv',
#  'SBE09_1387_20200511_0256_77_10_0394.cnv',
#  'SBE09_1387_20200511_0709_77_10_0395.cnv',
#  'SBE09_1387_20200511_1541_77_10_0396.cnv',
#  'SBE09_1387_20200511_2143_77_10_0397.cnv',
#  'SBE09_1387_20200512_0036_77_10_0398.cnv',
#  'SBE09_1387_20200512_0403_77_10_0399.cnv',
#  'SBE09_1387_20200512_1150_77_10_0400.cnv',
#  'SBE09_1387_20200512_1527_77_10_0401.cnv',
#  'SBE09_1387_20200512_1812_77_10_0402.cnv',
#  'SBE09_1387_20200512_1922_77_10_0403.cnv',
#  'SBE09_1387_20200512_2028_77_10_0404.cnv',
#  'SBE09_1387_20200512_2207_77_10_0405.cnv',
#  'SBE09_1387_20200513_0002_77_10_0406.cnv',
#  'SBE09_1387_20200513_1111_77_10_0407.cnv',
#  'SBE09_1387_20200514_0450_77_10_0408.cnv',
#  'SBE09_1387_20200514_1153_77_10_0409.cnv',
#  'SBE09_1387_20200514_1501_77_10_0410.cnv',
#  'SBE09_1387_20200514_2234_77_10_0411.cnv']

# %%
##################        SAVE DATA ACCORDING TO CTD STANDARD FORMAT (TXT)        ###################

start_time = time.time()

data_path = s.save_data(datasets, 
                        writer='ctd_standard_template', 
                        return_data_path=True)

print("Datasets saved--%.3f sec\n" % (time.time() - start_time))

print('Path to saved data: \n{}'.format(data_path))
# Out:
# Datasets saved--1.975 sec
#
# Path to saved data:
# C:\Utveckling\ctdpy\ctdpy/exports/ctd_std_fmt_20200526_095058/
