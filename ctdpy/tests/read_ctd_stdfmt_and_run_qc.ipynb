# %%
import sys
sys.path.append('C:\\Utveckling\\sharkpylib')
sys.path.append('C:\\Utveckling\\ctdpy')  #  

from ctdpy.core.session import Session
from ctdpy.core.utils import generate_filepaths, get_reversed_dictionary

from sharkpylib.qc.qc_default import QCBlueprint

import time
from pprint import pprint

# %%
###################        GET FILES        #################### 

# base_dir = 'C:\\Utveckling\\ctdpy\\ctdpy\\tests\\etc\\ctd_std_fmt_expedition_april_2020'
# base_dir = 'C:\\Temp\\CTD_DV\\ctd_std_fmt_20200526_095058'
base_dir = 'C:\\Arbetsmapp\\datasets\\Profile\\2018\\SHARK_Profile_2018_BAS_SMHI\\processed_data'

files = generate_filepaths(base_dir,
                           endswith='.txt',                # Presumably CTD-standard format
                           only_from_dir=False,
                           )

# %%
###################        Create SESSION object        ###################

s = Session(filepaths=files,
            reader='ctd_stdfmt',
            )

# %%
###################        READ DELIVERY DATA, CNV, XLSX        ###################

start_time = time.time()

datasets = s.read()

print("Datasets loaded--%.3f sec" % (time.time() - start_time))
# Out:
# dataset txt
# we have data
# Datasets loaded--11.378 sec

# %%
print('Files loaded:')
pprint(list(datasets[0]))
# Out:
# Files loaded:
# ['ctd_profile_20180118_26DA_0103.txt',
#  'ctd_profile_20180118_26DA_0105.txt',
#  'ctd_profile_20180119_26DA_0111.txt',
#  'ctd_profile_20180119_26DA_0114.txt',
#  'ctd_profile_20180119_26DA_0116.txt',
#  'ctd_profile_20180120_26DA_0124.txt',
#  'ctd_profile_20180120_26DA_0126.txt',
#  'ctd_profile_20180120_26DA_0129.txt',
#  'ctd_profile_20180120_26DA_0132.txt',
#  'ctd_profile_20180121_26DA_0141.txt',
#  'ctd_profile_20180121_26DA_0143.txt',
#  'ctd_profile_20180121_26DA_0145.txt',
#  'ctd_profile_20180121_26DA_0148.txt',
#  'ctd_profile_20180122_26DA_0156.txt',
#  'ctd_profile_20180122_26DA_0159.txt',
#  'ctd_profile_20180122_26DA_0161.txt',
#  'ctd_profile_20180122_26DA_0164.txt',
#  'ctd_profile_20180122_26DA_0165.txt',
#  'ctd_profile_20180123_26DA_0176.txt',
#  'ctd_profile_20180123_26DA_0179.txt',
#  'ctd_profile_20180123_26DA_0181.txt',
#  'ctd_profile_20180124_26DA_0182.txt',
#  'ctd_profile_20180124_26DA_0185.txt',
#  'ctd_profile_20180124_26DA_0187.txt',
#  'ctd_profile_20180124_26DA_0189.txt',
#  'ctd_profile_20180124_347V_0001.txt',
#  'ctd_profile_20180124_347V_0002.txt',
#  'ctd_profile_20180124_347V_0003.txt',
#  'ctd_profile_20180124_347V_0004.txt',
#  'ctd_profile_20180125_26DA_0194.txt',
#  'ctd_profile_20180125_26DA_0196.txt',
#  'ctd_profile_20180125_26DA_0200.txt',
#  'ctd_profile_20180125_26DA_0203.txt',
#  'ctd_profile_20180125_347V_0005.txt',
#  'ctd_profile_20180125_347V_0006.txt',
#  'ctd_profile_20180125_347V_0007.txt',
#  'ctd_profile_20180125_347V_0008.txt',
#  'ctd_profile_20180125_347V_0009.txt',
#  'ctd_profile_20180125_347V_0010.txt',
#  'ctd_profile_20180126_26DA_0210.txt',
#  'ctd_profile_20180126_26DA_0212.txt',
#  'ctd_profile_20180126_26DA_0215.txt',
#  'ctd_profile_20180126_26DA_0216.txt',
#  'ctd_profile_20180126_26DA_0220.txt',
#  'ctd_profile_20180126_26DA_0221.txt',
#  'ctd_profile_20180126_347V_0011.txt',
#  'ctd_profile_20180126_347V_0012.txt',
#  'ctd_profile_20180126_347V_0013.txt',
#  'ctd_profile_20180126_347V_0014.txt',
#  'ctd_profile_20180126_347V_0015.txt',
#  'ctd_profile_20180126_347V_0016.txt',
#  'ctd_profile_20180127_26DA_0230.txt',
#  'ctd_profile_20180127_26DA_0233.txt',
#  'ctd_profile_20180127_26DA_0235.txt',
#  'ctd_profile_20180127_26DA_0237.txt',
#  'ctd_profile_20180127_347V_0017.txt',
#  'ctd_profile_20180127_347V_0018.txt',
#  'ctd_profile_20180127_347V_0019.txt',
#  'ctd_profile_20180127_347V_0020.txt',
#  'ctd_profile_20180127_347V_0021.txt',
#  'ctd_profile_20180127_347V_0022.txt',
#  'ctd_profile_20180128_26DA_0241.txt',
#  'ctd_profile_20180128_26DA_0244.txt',
#  'ctd_profile_20180128_26DA_0246.txt',
#  'ctd_profile_20180128_26DA_0248.txt',
#  'ctd_profile_20180128_347V_0023.txt',
#  'ctd_profile_20180128_347V_0024.txt',
#  'ctd_profile_20180128_347V_0025.txt',
#  'ctd_profile_20180128_347V_0026.txt',
#  'ctd_profile_20180128_347V_0027.txt',
#  'ctd_profile_20180129_26DA_0251.txt',
#  'ctd_profile_20180129_26DA_0254.txt',
#  'ctd_profile_20180129_26DA_0255.txt',
#  'ctd_profile_20180129_26DA_0258.txt',
#  'ctd_profile_20180129_347V_0028.txt',
#  'ctd_profile_20180129_347V_0029.txt',
#  'ctd_profile_20180129_347V_0030.txt',
#  'ctd_profile_20180129_347V_0031.txt',
#  'ctd_profile_20180129_347V_0032.txt',
#  'ctd_profile_20180130_26DA_0263.txt',
#  'ctd_profile_20180130_347V_0033.txt',
#  'ctd_profile_20180130_347V_0034.txt',
#  'ctd_profile_20180130_347V_0035.txt',
#  'ctd_profile_20180130_347V_0036.txt',
#  'ctd_profile_20180131_347V_0037.txt',
#  'ctd_profile_20180131_347V_0038.txt',
#  'ctd_profile_20180131_347V_0039.txt',
#  'ctd_profile_20180131_347V_0040.txt',
#  'ctd_profile_20180201_347V_0041.txt',
#  'ctd_profile_20180201_347V_0042.txt',
#  'ctd_profile_20180201_347V_0043.txt',
#  'ctd_profile_20180201_347V_0044.txt',
#  'ctd_profile_20180202_347V_0045.txt',
#  'ctd_profile_20180202_347V_0046.txt',
#  'ctd_profile_20180202_347V_0047.txt',
#  'ctd_profile_20180202_347V_0048.txt',
#  'ctd_profile_20180203_347V_0049.txt',
#  'ctd_profile_20180203_347V_0050.txt',
#  'ctd_profile_20180203_347V_0051.txt',
#  'ctd_profile_20180203_347V_0052.txt',
#  'ctd_profile_20180203_347V_0053.txt',
#  'ctd_profile_20180203_347V_0054.txt',
#  'ctd_profile_20180203_347V_0055.txt',
#  'ctd_profile_20180203_347V_0056.txt',
#  'ctd_profile_20180204_347V_0057.txt',
#  'ctd_profile_20180225_26DA_0301.txt',
#  'ctd_profile_20180225_26DA_0303.txt',
#  'ctd_profile_20180225_26DA_0305.txt',
#  'ctd_profile_20180225_26DA_0307.txt',
#  'ctd_profile_20180225_26DA_0310.txt',
#  'ctd_profile_20180226_26DA_0311.txt',
#  'ctd_profile_20180226_26DA_0314.txt',
#  'ctd_profile_20180226_26DA_0316.txt',
#  'ctd_profile_20180226_26DA_0317.txt',
#  'ctd_profile_20180226_26DA_0320.txt',
#  'ctd_profile_20180227_26DA_0321.txt',
#  'ctd_profile_20180227_26DA_0323.txt',
#  'ctd_profile_20180227_26DA_0326.txt',
#  'ctd_profile_20180227_26DA_0327.txt',
#  'ctd_profile_20180228_26DA_0329.txt',
#  'ctd_profile_20180228_26DA_0331.txt',
#  'ctd_profile_20180228_26DA_0333.txt',
#  'ctd_profile_20180301_26DA_0335.txt',
#  'ctd_profile_20180301_26DA_0337.txt',
#  'ctd_profile_20180301_26DA_0339.txt',
#  'ctd_profile_20180301_26DA_0342.txt',
#  'ctd_profile_20180302_26DA_0343.txt',
#  'ctd_profile_20180302_26DA_0346.txt',
#  'ctd_profile_20180302_26DA_0347.txt',
#  'ctd_profile_20180303_26DA_0349.txt',
#  'ctd_profile_20180303_26DA_0351.txt',
#  'ctd_profile_20180303_26DA_0354.txt',
#  'ctd_profile_20180304_26DA_0355.txt',
#  'ctd_profile_20180304_26DA_0357.txt',
#  'ctd_profile_20180304_26DA_0359.txt',
#  'ctd_profile_20180304_26DA_0361.txt',
#  'ctd_profile_20180304_26DA_0364.txt',
#  'ctd_profile_20180305_26DA_0365.txt',
#  'ctd_profile_20180305_26DA_0368.txt',
#  'ctd_profile_20180305_26DA_0370.txt',
#  'ctd_profile_20180314_347V_0058.txt',
#  'ctd_profile_20180315_347V_0059.txt',
#  'ctd_profile_20180316_347V_0060.txt',
#  'ctd_profile_20180317_347V_0061.txt',
#  'ctd_profile_20180318_347V_0062.txt',
#  'ctd_profile_20180318_347V_0063.txt',
#  'ctd_profile_20180318_347V_0064.txt',
#  'ctd_profile_20180318_347V_0065.txt',
#  'ctd_profile_20180318_347V_0066.txt',
#  'ctd_profile_20180319_347V_0067.txt',
#  'ctd_profile_20180319_347V_0068.txt',
#  'ctd_profile_20180319_347V_0069.txt',
#  'ctd_profile_20180319_347V_0070.txt',
#  'ctd_profile_20180319_347V_0071.txt',
#  'ctd_profile_20180319_347V_0072.txt',
#  'ctd_profile_20180319_347V_0073.txt',
#  'ctd_profile_20180320_347V_0074.txt',
#  'ctd_profile_20180320_347V_0075.txt',
#  'ctd_profile_20180320_347V_0076.txt',
#  'ctd_profile_20180415_34EB_0001.txt',
#  'ctd_profile_20180415_34EB_0002.txt',
#  'ctd_profile_20180416_34EB_0003.txt',
#  'ctd_profile_20180416_34EB_0004.txt',
#  'ctd_profile_20180416_34EB_0005.txt',
#  'ctd_profile_20180416_34EB_0006.txt',
#  'ctd_profile_20180416_34EB_0007.txt',
#  'ctd_profile_20180416_34EB_0008.txt',
#  'ctd_profile_20180416_34EB_0009.txt',
#  'ctd_profile_20180416_34EB_0010.txt',
#  'ctd_profile_20180417_34EB_0011.txt',
#  'ctd_profile_20180417_34EB_0012.txt',
#  'ctd_profile_20180417_34EB_0013.txt',
#  'ctd_profile_20180417_34EB_0014.txt',
#  'ctd_profile_20180418_34EB_0015.txt',
#  'ctd_profile_20180418_34EB_0016.txt',
#  'ctd_profile_20180418_34EB_0017.txt',
#  'ctd_profile_20180418_34EB_0018.txt',
#  'ctd_profile_20180419_34EB_0019.txt',
#  'ctd_profile_20180419_34EB_0020.txt',
#  'ctd_profile_20180419_34EB_0021.txt',
#  'ctd_profile_20180419_34EB_0022.txt',
#  'ctd_profile_20180420_34EB_0023.txt',
#  'ctd_profile_20180420_34EB_0024.txt',
#  'ctd_profile_20180421_34EB_0025.txt',
#  'ctd_profile_20180526_34EB_0026.txt',
#  'ctd_profile_20180526_34EB_0027.txt',
#  'ctd_profile_20180526_34EB_0028.txt',
#  'ctd_profile_20180527_34EB_0029.txt',
#  'ctd_profile_20180527_34EB_0030.txt',
#  'ctd_profile_20180527_34EB_0031.txt',
#  'ctd_profile_20180527_34EB_0032.txt',
#  'ctd_profile_20180527_34EB_0033.txt',
#  'ctd_profile_20180527_34EB_0034.txt',
#  'ctd_profile_20180527_34EB_0035.txt',
#  'ctd_profile_20180528_34EB_0036.txt',
#  'ctd_profile_20180528_34EB_0037.txt',
#  'ctd_profile_20180528_34EB_0038.txt',
#  'ctd_profile_20180528_34EB_0039.txt',
#  'ctd_profile_20180528_34EB_0040.txt',
#  'ctd_profile_20180529_34EB_0041.txt',
#  'ctd_profile_20180529_34EB_0042.txt',
#  'ctd_profile_20180529_34EB_0043.txt',
#  'ctd_profile_20180530_34EB_0044.txt',
#  'ctd_profile_20180530_34EB_0045.txt',
#  'ctd_profile_20180530_34EB_0046.txt',
#  'ctd_profile_20180530_34EB_0047.txt',
#  'ctd_profile_20180530_34EB_0048.txt',
#  'ctd_profile_20180531_34EB_0049.txt',
#  'ctd_profile_20180531_34EB_0050.txt',
#  'ctd_profile_20180531_34EB_0051.txt',
#  'ctd_profile_20180820_26DA_0801.txt',
#  'ctd_profile_20180821_26DA_0820.txt',
#  'ctd_profile_20180821_26DA_0822.txt',
#  'ctd_profile_20180821_26DA_0825.txt',
#  'ctd_profile_20180821_26DA_0827.txt',
#  'ctd_profile_20180822_26DA_0839.txt',
#  'ctd_profile_20180822_26DA_0842.txt',
#  'ctd_profile_20180822_26DA_0844.txt',
#  'ctd_profile_20180822_26DA_0846.txt',
#  'ctd_profile_20180822_26DA_0848.txt',
#  'ctd_profile_20180823_26DA_0861.txt',
#  'ctd_profile_20180823_26DA_0864.txt',
#  'ctd_profile_20180823_26DA_0866.txt',
#  'ctd_profile_20180823_26DA_0868.txt',
#  'ctd_profile_20180823_26DA_0870.txt',
#  'ctd_profile_20180824_26DA_0881.txt',
#  'ctd_profile_20180824_26DA_0884.txt',
#  'ctd_profile_20180824_26DA_0886.txt',
#  'ctd_profile_20180824_26DA_0888.txt',
#  'ctd_profile_20180825_26DA_0889.txt',
#  'ctd_profile_20180825_26DA_0892.txt',
#  'ctd_profile_20180825_26DA_0893.txt',
#  'ctd_profile_20180825_26DA_0895.txt',
#  'ctd_profile_20180826_26DA_0897.txt',
#  'ctd_profile_20180826_26DA_0899.txt',
#  'ctd_profile_20180826_26DA_0901.txt',
#  'ctd_profile_20180826_26DA_0903.txt',
#  'ctd_profile_20180826_26DA_0906.txt',
#  'ctd_profile_20180827_26DA_0907.txt',
#  'ctd_profile_20180827_26DA_0909.txt',
#  'ctd_profile_20180827_26DA_0913.txt',
#  'ctd_profile_20180827_26DA_0915.txt',
#  'ctd_profile_20180827_26DA_0917.txt',
#  'ctd_profile_20180827_26DA_0918.txt',
#  'ctd_profile_20180828_26DA_0919.txt',
#  'ctd_profile_20180828_26DA_0922.txt',
#  'ctd_profile_20180828_26DA_0923.txt',
#  'ctd_profile_20180828_26DA_0925.txt',
#  'ctd_profile_20180828_26DA_0928.txt',
#  'ctd_profile_20180829_26DA_0929.txt',
#  'ctd_profile_20180829_26DA_0931.txt',
#  'ctd_profile_20180829_26DA_0933.txt',
#  'ctd_profile_20180829_26DA_0935.txt',
#  'ctd_profile_20180829_26DA_0936.txt',
#  'ctd_profile_20180829_26DA_0939.txt',
#  'ctd_profile_20180830_26DA_0940.txt',
#  'ctd_profile_20180830_26DA_0944.txt',
#  'ctd_profile_20180830_26DA_0949.txt',
#  'ctd_profile_20180830_26DA_0950.txt',
#  'ctd_profile_20180902_26DA_0951.txt',
#  'ctd_profile_20180903_26DA_0952.txt',
#  'ctd_profile_20180903_26DA_0953.txt',
#  'ctd_profile_20180903_26DA_0954.txt',
#  'ctd_profile_20180903_26DA_0955.txt',
#  'ctd_profile_20180903_26DA_0956.txt',
#  'ctd_profile_20180903_26DA_0957.txt',
#  'ctd_profile_20180904_26DA_0958.txt',
#  'ctd_profile_20180904_26DA_0959.txt',
#  'ctd_profile_20180904_26DA_0960.txt',
#  'ctd_profile_20180904_26DA_0961.txt',
#  'ctd_profile_20180905_26DA_0962.txt',
#  'ctd_profile_20180905_26DA_0964.txt',
#  'ctd_profile_20180905_26DA_0965.txt',
#  'ctd_profile_20180906_26DA_0966.txt',
#  'ctd_profile_20180920_34AR_0034.txt',
#  'ctd_profile_20180921_34AR_0035.txt',
#  'ctd_profile_20180921_34AR_0036.txt',
#  'ctd_profile_20180921_34AR_0037.txt',
#  'ctd_profile_20180922_34AR_0038.txt',
#  'ctd_profile_20180922_34AR_0039.txt',
#  'ctd_profile_20180922_34AR_0040.txt',
#  'ctd_profile_20180923_34AR_0041.txt',
#  'ctd_profile_20180923_34AR_0042.txt',
#  'ctd_profile_20180923_34AR_0043.txt',
#  'ctd_profile_20180924_34AR_0044.txt',
#  'ctd_profile_20180924_34AR_0045.txt',
#  'ctd_profile_20180924_34AR_0046.txt',
#  'ctd_profile_20180924_34AR_0047.txt',
#  'ctd_profile_20180924_34AR_0048.txt',
#  'ctd_profile_20180924_34AR_0049.txt',
#  'ctd_profile_20181003_26DA_1001.txt',
#  'ctd_profile_20181003_26DA_1003.txt',
#  'ctd_profile_20181004_26DA_1005.txt',
#  'ctd_profile_20181004_26DA_1007.txt',
#  'ctd_profile_20181004_26DA_1009.txt',
#  'ctd_profile_20181004_26DA_1011.txt',
#  'ctd_profile_20181005_26DA_1013.txt',
#  'ctd_profile_20181005_26DA_1015.txt',
#  'ctd_profile_20181005_26DA_1017.txt',
#  'ctd_profile_20181005_26DA_1019.txt',
#  'ctd_profile_20181006_26DA_1021.txt',
#  'ctd_profile_20181006_26DA_1023.txt',
#  'ctd_profile_20181006_26DA_1025.txt',
#  'ctd_profile_20181006_26DA_1027.txt',
#  'ctd_profile_20181006_26DA_1029.txt',
#  'ctd_profile_20181007_26DA_1031.txt',
#  'ctd_profile_20181007_26DA_1033.txt',
#  'ctd_profile_20181007_26DA_1035.txt',
#  'ctd_profile_20181007_26DA_1037.txt',
#  'ctd_profile_20181007_26DA_1039.txt',
#  'ctd_profile_20181008_26DA_1041.txt',
#  'ctd_profile_20181008_26DA_1043.txt',
#  'ctd_profile_20181008_26DA_1046.txt',
#  'ctd_profile_20181009_26DA_1048.txt',
#  'ctd_profile_20181009_26DA_1050.txt',
#  'ctd_profile_20181009_26DA_1052.txt',
#  'ctd_profile_20181009_26DA_1054.txt',
#  'ctd_profile_20181010_26DA_1056.txt',
#  'ctd_profile_20181010_26DA_1058.txt',
#  'ctd_profile_20181010_26DA_1060.txt',
#  'ctd_profile_20181010_26DA_1062.txt',
#  'ctd_profile_20181010_26DA_1064.txt',
#  'ctd_profile_20181011_26DA_1066.txt',
#  'ctd_profile_20181011_26DA_1068.txt',
#  'ctd_profile_20181011_26DA_1070.txt',
#  'ctd_profile_20181011_26DA_1072.txt',
#  'ctd_profile_20181011_26DA_1074.txt',
#  'ctd_profile_20181012_26DA_1076.txt',
#  'ctd_profile_20181012_26DA_1078.txt',
#  'ctd_profile_20181012_26DA_1080.txt',
#  'ctd_profile_20181012_26DA_1082.txt',
#  'ctd_profile_20181012_26DA_1084.txt',
#  'ctd_profile_20181012_26DA_1086.txt',
#  'ctd_profile_20181013_26DA_1088.txt',
#  'ctd_profile_20181013_26DA_1090.txt',
#  'ctd_profile_20181013_26DA_1092.txt',
#  'ctd_profile_20181013_26DA_1094.txt',
#  'ctd_profile_20181014_34AR_0090.txt',
#  'ctd_profile_20181014_34AR_0091.txt',
#  'ctd_profile_20181015_34AR_0092.txt',
#  'ctd_profile_20181015_34AR_0093.txt',
#  'ctd_profile_20181015_34AR_0094.txt',
#  'ctd_profile_20181015_34AR_0095.txt',
#  'ctd_profile_20181016_34AR_0096.txt',
#  'ctd_profile_20181016_34AR_0097.txt',
#  'ctd_profile_20181016_34AR_0098.txt',
#  'ctd_profile_20181016_34AR_0099.txt',
#  'ctd_profile_20181017_34AR_0100.txt',
#  'ctd_profile_20181017_34AR_0101.txt',
#  'ctd_profile_20181017_34AR_0102.txt',
#  'ctd_profile_20181017_34AR_0103.txt',
#  'ctd_profile_20181018_34AR_0104.txt',
#  'ctd_profile_20181018_34AR_0105.txt',
#  'ctd_profile_20181018_34AR_0106.txt',
#  'ctd_profile_20181018_34AR_0107.txt',
#  'ctd_profile_20181018_34AR_0108.txt',
#  'ctd_profile_20181018_34AR_0109.txt',
#  'ctd_profile_20181018_34AR_0110.txt',
#  'ctd_profile_20181018_34AR_0111.txt',
#  'ctd_profile_20181019_34AR_0112.txt',
#  'ctd_profile_20181019_34AR_0113.txt',
#  'ctd_profile_20181020_34AR_0114.txt',
#  'ctd_profile_20181020_34AR_0115.txt',
#  'ctd_profile_20181108_34AR_0117.txt',
#  'ctd_profile_20181108_34AR_0118.txt',
#  'ctd_profile_20181109_34AR_0119.txt',
#  'ctd_profile_20181109_34AR_0120.txt',
#  'ctd_profile_20181109_34AR_0121.txt',
#  'ctd_profile_20181109_34AR_0122.txt',
#  'ctd_profile_20181109_34AR_0123.txt',
#  'ctd_profile_20181110_34AR_0124.txt',
#  'ctd_profile_20181110_34AR_0125.txt',
#  'ctd_profile_20181110_34AR_0126.txt',
#  'ctd_profile_20181110_34AR_0127.txt',
#  'ctd_profile_20181111_34AR_0128.txt',
#  'ctd_profile_20181111_34AR_0129.txt',
#  'ctd_profile_20181111_34AR_0130.txt',
#  'ctd_profile_20181111_34AR_0131.txt',
#  'ctd_profile_20181111_34AR_0132.txt',
#  'ctd_profile_20181112_34AR_0133.txt',
#  'ctd_profile_20181112_34AR_0134.txt',
#  'ctd_profile_20181112_34AR_0135.txt',
#  'ctd_profile_20181112_34AR_0136.txt',
#  'ctd_profile_20181112_34AR_0137.txt',
#  'ctd_profile_20181112_34AR_0138.txt',
#  'ctd_profile_20181112_34AR_0139.txt',
#  'ctd_profile_20181112_34AR_0140.txt',
#  'ctd_profile_20181113_34AR_0141.txt',
#  'ctd_profile_20181113_34AR_0142.txt',
#  'ctd_profile_20181113_34AR_0143.txt',
#  'ctd_profile_20181114_34AR_0144.txt',
#  'ctd_profile_20181114_34AR_0145.txt',
#  'ctd_profile_20181114_34AR_0146.txt',
#  'ctd_profile_20181114_34AR_0147.txt',
#  'ctd_profile_20181114_34AR_0148.txt',
#  'ctd_profile_20181120_26DA_1201.txt',
#  'ctd_profile_20181120_26DA_1203.txt',
#  'ctd_profile_20181120_26DA_1205.txt',
#  'ctd_profile_20181121_26DA_1207.txt',
#  'ctd_profile_20181121_26DA_1210.txt',
#  'ctd_profile_20181121_26DA_1212.txt',
#  'ctd_profile_20181121_26DA_1215.txt',
#  'ctd_profile_20181122_26DA_1216.txt',
#  'ctd_profile_20181122_26DA_1219.txt',
#  'ctd_profile_20181122_26DA_1220.txt',
#  'ctd_profile_20181122_26DA_1223.txt',
#  'ctd_profile_20181123_26DA_1224.txt',
#  'ctd_profile_20181123_26DA_1226.txt',
#  'ctd_profile_20181123_26DA_1229.txt',
#  'ctd_profile_20181124_26DA_1230.txt',
#  'ctd_profile_20181124_26DA_1232.txt',
#  'ctd_profile_20181124_26DA_1234.txt',
#  'ctd_profile_20181124_26DA_1236.txt',
#  'ctd_profile_20181124_26DA_1238.txt',
#  'ctd_profile_20181124_26DA_1240.txt',
#  'ctd_profile_20181125_26DA_1242.txt',
#  'ctd_profile_20181125_26DA_1244.txt',
#  'ctd_profile_20181125_26DA_1246.txt',
#  'ctd_profile_20181126_26DA_1248.txt',
#  'ctd_profile_20181126_26DA_1250.txt',
#  'ctd_profile_20181126_26DA_1252.txt',
#  'ctd_profile_20181126_26DA_1255.txt',
#  'ctd_profile_20181127_26DA_1256.txt',
#  'ctd_profile_20181127_26DA_1259.txt',
#  'ctd_profile_20181128_26DA_1260.txt',
#  'ctd_profile_20181204_34AR_0149.txt',
#  'ctd_profile_20181204_34AR_0150.txt',
#  'ctd_profile_20181205_34AR_0151.txt',
#  'ctd_profile_20181205_34AR_0152.txt',
#  'ctd_profile_20181205_34AR_0153.txt',
#  'ctd_profile_20181205_34AR_0154.txt',
#  'ctd_profile_20181205_34AR_0155.txt',
#  'ctd_profile_20181206_34AR_0156.txt',
#  'ctd_profile_20181206_34AR_0157.txt',
#  'ctd_profile_20181206_34AR_0158.txt',
#  'ctd_profile_20181206_34AR_0159.txt',
#  'ctd_profile_20181207_34AR_0160.txt',
#  'ctd_profile_20181207_34AR_0161.txt',
#  'ctd_profile_20181207_34AR_0162.txt',
#  'ctd_profile_20181207_34AR_0163.txt',
#  'ctd_profile_20181207_34AR_0164.txt',
#  'ctd_profile_20181207_34AR_0165.txt',
#  'ctd_profile_20181208_34AR_0166.txt',
#  'ctd_profile_20181208_34AR_0167.txt',
#  'ctd_profile_20181208_34AR_0168.txt',
#  'ctd_profile_20181208_34AR_0169.txt',
#  'ctd_profile_20181208_34AR_0170.txt',
#  'ctd_profile_20181208_34AR_0171.txt',
#  'ctd_profile_20181208_34AR_0172.txt',
#  'ctd_profile_20181209_34AR_0173.txt',
#  'ctd_profile_20181209_34AR_0174.txt',
#  'ctd_profile_20181210_34AR_0175.txt',
#  'ctd_profile_20181210_34AR_0176.txt',
#  'ctd_profile_20181210_34AR_0177.txt',
#  'ctd_profile_20181210_34AR_0178.txt',
#  'ctd_profile_20181210_34AR_0179.txt']

# %%
##################        QUALITY CONTROL       ###################

start_time = time.time()

# This will produce alot of prints...

for data_key, item in datasets[0].items():
    # print(data_key)
    parameter_mapping = get_reversed_dictionary(s.settings.pmap, item['data'].keys())
    qc_run = QCBlueprint(item, parameter_mapping=parameter_mapping)
    qc_run()

print("QCBlueprint run--%.3f sec" % (time.time() - start_time))

# Auto QC performed. Q-flags inserted
# Out:
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# C:\Utveckling\sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# QC-Spike failed for DOXY_CTD [ml/l]
# QC - USER: a002028
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC - USER: a002028
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC - USER: a002028
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC - USER: a002028
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC - USER: a002028
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC - USER: a002028
# QC-Decreasing failed for DOXY_CTD [ml/l]
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC - USER: a002028
# QC-Decreasing failed for DOXY_CTD [ml/l]
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC-Spike failed for DOXY_CTD [ml/l]
# QC - USER: a002028
# QC-Decreasing failed for DOXY_CTD [ml/l]
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC-Decreasing failed for DOXY_CTD [ml/l]
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC - USER: a002028
# QC-Decreasing failed for DOXY_CTD [ml/l]
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC - USER: a002028
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC - USER: a002028
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-Increasing failed for SALT_CTD [psu (PSS-78)]
# QC-Increasing failed for SALT2_CTD [psu (PSS-78)]
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC - USER: a002028
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC - USER: a002028
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC - USER: a002028
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC - USER: a002028
# QC-Decreasing failed for PAR_CTD [µE/(cm2 sec)]
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC - USER: a002028
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC - USER: a002028
# QC-Decreasing failed for DOXY_CTD [ml/l]
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC-Range failed for DOXY_CTD [ml/l]
# QC - USER: a002028
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC - USER: a002028
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for CNDC2_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for CNDC2_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for DOXY_CTD [ml/l]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['CNDC_CTD [S/m]', 'CNDC2_CTD [S/m]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for DOXY_CTD [ml/l]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for DOXY_CTD [ml/l]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC - USER: a002028
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['CNDC_CTD [S/m]', 'CNDC2_CTD [S/m]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC - USER: a002028
# QC-Decreasing failed for DOXY_CTD [ml/l]
# QC-Decreasing failed for DOXY2_CTD [ml/l]
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-Increasing failed for SALT_CTD [psu (PSS-78)]
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC - USER: a002028
# QC-Decreasing failed for DOXY_CTD [ml/l]
# QC-Decreasing failed for DOXY2_CTD [ml/l]
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC - USER: a002028
# QC-Decreasing failed for DOXY_CTD [ml/l]
# QC-Decreasing failed for DOXY2_CTD [ml/l]
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC - USER: a002028
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Spike failed for DOXY_CTD [ml/l]
# QC - USER: a002028
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for DOXY2_CTD [ml/l]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for DOXY_CTD [ml/l]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-Range failed for TURB_CTD [NTU]
# QC-Spike failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-Decreasing failed for DOXY_CTD [ml/l]
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['CNDC_CTD [S/m]', 'CNDC2_CTD [S/m]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC - USER: a002028
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC-Spike failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC-Increasing failed for SALT_CTD [psu (PSS-78)]
# QC-Increasing failed for SALT2_CTD [psu (PSS-78)]
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Decreasing failed for DOXY2_CTD [ml/l]
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC-Spike failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-Decreasing failed for DOXY2_CTD [ml/l]
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['CNDC_CTD [S/m]', 'CNDC2_CTD [S/m]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC - USER: a002028
# QC-Decreasing failed for DOXY_CTD [ml/l]
# QC-Decreasing failed for DOXY2_CTD [ml/l]
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['CNDC_CTD [S/m]', 'CNDC2_CTD [S/m]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC-Increasing failed for SALT2_CTD [psu (PSS-78)]
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Range failed for DOXY_CTD [ml/l]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC - USER: a002028
# QC-Decreasing failed for DOXY_CTD [ml/l]
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for DOXY_CTD [ml/l]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC - USER: a002028
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC - USER: a002028
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC - USER: a002028
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC - USER: a002028
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC - USER: a002028
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC - USER: a002028
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC - USER: a002028
# QC-Decreasing failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC - USER: a002028
# QC - USER: a002028
# QC-Decreasing failed for PAR_CTD [µE/(cm2 sec)]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Range failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Range failed for TURB_CTD [NTU]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC - USER: a002028
# QC-Range failed for PHYC_CTD [ppb]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Range failed for PHYC_CTD [ppb]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Range failed for PHYC_CTD [ppb]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PHYC_CTD [ppb]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Range failed for CHLFLUO_CTD [mg/m3]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC-Increasing failed for SALT_CTD [psu (PSS-78)]
# QC-Increasing failed for SALT2_CTD [psu (PSS-78)]
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for CNDC2_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC - USER: a002028
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC - USER: a002028
# QC-Decreasing failed for PAR_CTD [µE/(cm2 sec)]
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC - USER: a002028
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PHYC_CTD [ppb]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Decreasing failed for PAR_CTD [µE/(cm2 sec)]
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Decreasing failed for PAR_CTD [µE/(cm2 sec)]
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC-Increasing failed for SALT_CTD [psu (PSS-78)]
# QC-Increasing failed for SALT2_CTD [psu (PSS-78)]
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-Increasing failed for SALT_CTD [psu (PSS-78)]
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for CNDC2_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Range failed for DOXY_CTD [ml/l]
# QC-Range failed for DOXY2_CTD [ml/l]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Range failed for DOXY2_CTD [ml/l]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for DOXY2_CTD [ml/l]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC-Spike failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for DOXY_CTD [ml/l]
# QC-Range failed for DOXY2_CTD [ml/l]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Range failed for DOXY_CTD [ml/l]
# QC-Range failed for DOXY2_CTD [ml/l]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for DOXY_CTD [ml/l]
# QC-Range failed for DOXY2_CTD [ml/l]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Decreasing failed for PAR_CTD [µE/(cm2 sec)]
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for DOXY2_CTD [ml/l]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Decreasing failed for PAR_CTD [µE/(cm2 sec)]
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# ...
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-Decreasing failed for DOXY_CTD [ml/l]
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Range failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-Decreasing failed for PAR_CTD [µE/(cm2 sec)]
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC - USER: a002028
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC - USER: a002028
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-Range failed for DOXY_CTD [ml/l]
# QC-Range failed for DOXY2_CTD [ml/l]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC - USER: a002028
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC - USER: a002028
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Spike failed for DOXY_CTD [ml/l]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC - USER: a002028
# QC - USER: a002028
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC - USER: a002028
# QC-Decreasing failed for PAR_CTD [µE/(cm2 sec)]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Spike failed for DENS_CTD [kg/m3]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-DataDiff failed for ['DENS_CTD [kg/m3]', 'DENS2_CTD [kg/m3]']
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for TURB_CTD [NTU]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Decreasing failed for PAR_CTD [µE/(cm2 sec)]
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Decreasing failed for DOXY2_CTD [ml/l]
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Range failed for TURB_CTD [NTU]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-Increasing failed for SALT_CTD [psu (PSS-78)]
# QC-Increasing failed for SALT2_CTD [psu (PSS-78)]
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Range failed for TURB_CTD [NTU]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC - USER: a002028
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Spike failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC - USER: a002028
# QC-Range failed for CHLFLUO_CTD [mg/m3]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC - USER: a002028
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC - USER: a002028
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Range failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for TURB_CTD [NTU]
# QC - USER: a002028
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for PHYC_CTD [ppb]
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for PHYC_CTD [ppb]
# QCBlueprint run--81.104 sec

# %%
first_ds = list(datasets[0])[0]

print('Note format of flagfield')
print(datasets[0][first_ds]['data']['Q0_TEMP_CTD'][:5])

print('\nDataframe from file: {}'.format(first_ds))
datasets[0][first_ds]['metadata']
# Out:
# Note format of flagfield
# 0    A00AA
# 1    A00AA
# 2    A00AA
# 3    A00AA
# 4    A00AA
# Name: Q0_TEMP_CTD, dtype: object
#
# Dataframe from file: ctd_profile_20180118_26DA_0103.txt
# 0                                       //FORMAT=PROFILE
# 1                                 //METADATA_DELIMITER=;
# 2                                    //DATA_DELIMITER=\t
# 3                                  //METADATA;MYEAR;2018
# 4                                //METADATA;PROJ;IBT,NAT
#                              ...
# 447    //INSTRUMENT_METADATA;# split_date = Mar 27 20...
# 448    //INSTRUMENT_METADATA;# split_in = C:\ctd\temp...
# 449    //INSTRUMENT_METADATA;# split_excl_bad_scans =...
# 450            //INSTRUMENT_METADATA;# file_type = ascii
# 452    //COMNT_QC; AUTOMATIC QC PERFORMED BY a002028;...
# Length: 452, dtype: object

# %%
#  ##################        UPDATE DATA ACCORDING TO CTD TEMPLATE (TXT-FORMAT)        ###################

# As of now we only export the updated ctd-datafile (ctd-standard-format). 
# delivery_note, metadata, sensorinfo, information are exclude.. (will be included..#TODO..)

start_time = time.time()

data_path = s.save_data(datasets, writer='ctd_standard_template', return_data_path=True)

print("Datasets saved--%.3f sec" % (time.time() - start_time))
# Out:
# Datasets saved--3.379 sec

# %%
s.settings.pmap
# Out:
# {'SALT2_CTD': 'SALT2_CTD',
#  'salt2_ctd': 'SALT2_CTD',
#  'SALT2_CTD [psu (PSS-78)]': 'SALT2_CTD',
#  'salt2_ctd [psu (pss-78)]': 'SALT2_CTD',
#  'Salthalt2': 'SALT2_CTD',
#  'salthalt2': 'SALT2_CTD',
#  'sal11: Salinity, Practical, 2 [PSU]': 'SALT2_CTD',
#  'sal11: salinity, practical, 2 [psu]': 'SALT2_CTD',
#  'DESC_RATE_CTD': 'DESC_RATE_CTD',
#  'desc_rate_ctd': 'DESC_RATE_CTD',
#  'DESC_RATE_CTD [m/s]': 'DESC_RATE_CTD',
#  'desc_rate_ctd [m/s]': 'DESC_RATE_CTD',
#  'fallhastighet': 'DESC_RATE_CTD',
#  'dz/dtM: Descent Rate [m/s], WS': 'DESC_RATE_CTD',
#  'dz/dtm: descent rate [m/s], ws': 'DESC_RATE_CTD',
#  'dz/dtM: Descent Rate [m/s]': 'DESC_RATE_CTD',
#  'dz/dtm: descent rate [m/s]': 'DESC_RATE_CTD',
#  'ALTM_CTD': 'ALTM_CTD',
#  'altm_ctd': 'ALTM_CTD',
#  'ALTM_CTD [m]': 'ALTM_CTD',
#  'altm_ctd [m]': 'ALTM_CTD',
#  'Altimeter': 'ALTM_CTD',
#  'altimeter': 'ALTM_CTD',
#  'altM: Altimeter [m]': 'ALTM_CTD',
#  'altm: altimeter [m]': 'ALTM_CTD',
#  'TEMP_CTD': 'TEMP_CTD',
#  'temp_ctd': 'TEMP_CTD',
#  'TEMP_CTD [°C (ITS-90)]': 'TEMP_CTD',
#  'temp_ctd [°c (its-90)]': 'TEMP_CTD',
#  'TEMP_CTD [°C]': 'TEMP_CTD',
#  'temp_ctd [°c]': 'TEMP_CTD',
#  'Temperatur': 'TEMP_CTD',
#  'temperatur': 'TEMP_CTD',
#  't090C: Temperature [ITS-90, deg C]': 'TEMP_CTD',
#  't090c: temperature [its-90, deg c]': 'TEMP_CTD',
#  'tv290C: Temperature [ITS-90, deg C]': 'TEMP_CTD',
#  'tv290c: temperature [its-90, deg c]': 'TEMP_CTD',
#  'Temperature [ITS-90, deg C]': 'TEMP_CTD',
#  'temperature [its-90, deg c]': 'TEMP_CTD',
#  'Temp': 'TEMP_CTD',
#  'temp': 'TEMP_CTD',
#  'CNDC2_CTD': 'CNDC2_CTD',
#  'cndc2_ctd': 'CNDC2_CTD',
#  'CNDC2_CTD [S/m]': 'CNDC2_CTD',
#  'cndc2_ctd [s/m]': 'CNDC2_CTD',
#  'Konduktivitet2': 'CNDC2_CTD',
#  'konduktivitet2': 'CNDC2_CTD',
#  'c1S/m: Conductivity, 2 [S/m]': 'CNDC2_CTD',
#  'c1s/m: conductivity, 2 [s/m]': 'CNDC2_CTD',
#  'DELTA_TEMP_CTD': 'DELTA_TEMP_CTD',
#  'delta_temp_ctd': 'DELTA_TEMP_CTD',
#  'temperatur delta': 'DELTA_TEMP_CTD',
#  'T2-T190C: Temperature Difference, 2 - 1 [ITS-90, deg C]': 'DELTA_TEMP_CTD',
#  't2-t190c: temperature difference, 2 - 1 [its-90, deg c]': 'DELTA_TEMP_CTD',
#  'YELLOW_CTD': 'YELLOW_CTD',
#  'yellow_ctd': 'YELLOW_CTD',
#  'Gulämne': 'YELLOW_CTD',
#  'gulämne': 'YELLOW_CTD',
#  'haardtY: Fluorescence, Dr. Haardt Yellow Sub': 'YELLOW_CTD',
#  'haardty: fluorescence, dr. haardt yellow sub': 'YELLOW_CTD',
#  'SVEL2_CTD': 'SVEL2_CTD',
#  'svel2_ctd': 'SVEL2_CTD',
#  'SVEL2_CTD [m/s]': 'SVEL2_CTD',
#  'svel2_ctd [m/s]': 'SVEL2_CTD',
#  'Ljudhastighet2': 'SVEL2_CTD',
#  'ljudhastighet2': 'SVEL2_CTD',
#  'svCM1: Sound Velocity, 2 [Chen-Millero, m/s]': 'SVEL2_CTD',
#  'svcm1: sound velocity, 2 [chen-millero, m/s]': 'SVEL2_CTD',
#  'DOXY_CTD': 'DOXY_CTD',
#  'doxy_ctd': 'DOXY_CTD',
#  'DOXY_CTD [ml/l]': 'DOXY_CTD',
#  'doxy_ctd [ml/l]': 'DOXY_CTD',
#  'Syrgashalt': 'DOXY_CTD',
#  'syrgashalt': 'DOXY_CTD',
#  'sbeox0ML/L: Oxygen, SBE 43 [ml/l]': 'DOXY_CTD',
#  'sbeox0ml/l: oxygen, sbe 43 [ml/l]': 'DOXY_CTD',
#  'sbeox0ML/L: Oxygen, SBE 43 [ml/l], WS': 'DOXY_CTD',
#  'sbeox0ml/l: oxygen, sbe 43 [ml/l], ws': 'DOXY_CTD',
#  'sbeox0ML/L: Oxygen [ml/l], WS': 'DOXY_CTD',
#  'sbeox0ml/l: oxygen [ml/l], ws': 'DOXY_CTD',
#  'sbeox0ML/L: Oxygen, [ml/l], WS = 2': 'DOXY_CTD',
#  'sbeox0ml/l: oxygen, [ml/l], ws = 2': 'DOXY_CTD',
#  'DO_ml': 'DOXY_CTD',
#  'do_ml': 'DOXY_CTD',
#  'DOXY_SAT_CTD': 'DOXY_SAT_CTD',
#  'doxy_sat_ctd': 'DOXY_SAT_CTD',
#  'DO': 'DOXY_SAT_CTD',
#  'do': 'DOXY_SAT_CTD',
#  'sat': 'DOXY_SAT_CTD',
#  'PUMP_CTD': 'PUMP_CTD',
#  'pump_ctd': 'PUMP_CTD',
#  'PUMP_CTD []': 'PUMP_CTD',
#  'pump_ctd []': 'PUMP_CTD',
#  'pump status': 'PUMP_CTD',
#  'pumps: Pump Status': 'PUMP_CTD',
#  'pumps: pump status': 'PUMP_CTD',
#  'DENS2_CTD': 'DENS2_CTD',
#  'dens2_ctd': 'DENS2_CTD',
#  'DENS2_CTD [kg/m3]': 'DENS2_CTD',
#  'dens2_ctd [kg/m3]': 'DENS2_CTD',
#  'Densitet2': 'DENS2_CTD',
#  'densitet2': 'DENS2_CTD',
#  'sigma-t11: Density, 2 [sigma-t, Kg/m^3 ]': 'DENS2_CTD',
#  'sigma-t11: density, 2 [sigma-t, kg/m^3 ]': 'DENS2_CTD',
#  'CNDC_CTD': 'CNDC_CTD',
#  'cndc_ctd': 'CNDC_CTD',
#  'CNDC_CTD [S/m]': 'CNDC_CTD',
#  'cndc_ctd [s/m]': 'CNDC_CTD',
#  'CNDC_CTD [mS/cm]': 'CNDC_CTD',
#  'cndc_ctd [ms/cm]': 'CNDC_CTD',
#  'Konduktivitet': 'CNDC_CTD',
#  'konduktivitet': 'CNDC_CTD',
#  'c0S/m: Conductivity [S/m]': 'CNDC_CTD',
#  'c0s/m: conductivity [s/m]': 'CNDC_CTD',
#  'Cond': 'CNDC_CTD',
#  'cond': 'CNDC_CTD',
#  'TURB_CTD': 'TURB_CTD',
#  'turb_ctd': 'TURB_CTD',
#  'TURB_CTD [NTU]': 'TURB_CTD',
#  'turb_ctd [ntu]': 'TURB_CTD',
#  'Turbiditet': 'TURB_CTD',
#  'turbiditet': 'TURB_CTD',
#  'turbWETntu0: Turbidity, WET Labs ECO [NTU]': 'TURB_CTD',
#  'turbwetntu0: turbidity, wet labs eco [ntu]': 'TURB_CTD',
#  'CRUISE_NO': 'CRUISE_NO',
#  'cruise_no': 'CRUISE_NO',
#  'Cruise': 'CRUISE_NO',
#  'cruise': 'CRUISE_NO',
#  'STATN': 'STATN',
#  'statn': 'STATN',
#  'Station': 'STATN',
#  'station': 'STATN',
#  'SHIPC': 'SHIPC',
#  'shipc': 'SHIPC',
#  'Ship': 'SHIPC',
#  'ship': 'SHIPC',
#  'SERNO': 'SERNO',
#  'serno': 'SERNO',
#  'LIMS Job': 'SERNO',
#  'lims job': 'SERNO',
#  'PRES_CTD': 'PRES_CTD',
#  'pres_ctd': 'PRES_CTD',
#  'PRES_CTD [dbar]': 'PRES_CTD',
#  'pres_ctd [dbar]': 'PRES_CTD',
#  'Tryck': 'PRES_CTD',
#  'tryck': 'PRES_CTD',
#  'prDM: Pressure, Digiquartz [db]': 'PRES_CTD',
#  'prdm: pressure, digiquartz [db]': 'PRES_CTD',
#  'Pressure, Strain Gauge [db]': 'PRES_CTD',
#  'pressure, strain gauge [db]': 'PRES_CTD',
#  'prdM: Pressure, Strain Gauge [db]': 'PRES_CTD',
#  'prdm: pressure, strain gauge [db]': 'PRES_CTD',
#  'Press': 'PRES_CTD',
#  'press': 'PRES_CTD',
#  'SDATE': 'SDATE',
#  'sdate': 'SDATE',
#  'NMEA UTC': 'SDATE',
#  'nmea utc': 'SDATE',
#  'System UTC': 'SDATE',
#  'system utc': 'SDATE',
#  'start_time': 'SDATE',
#  'IntD': 'SDATE',
#  'intd': 'SDATE',
#  'STIME': 'STIME',
#  'stime': 'STIME',
#  'IntT': 'STIME',
#  'intt': 'STIME',
#  'YEAR': 'YEAR',
#  'year': 'YEAR',
#  'MONTH': 'MONTH',
#  'month': 'MONTH',
#  'DAY': 'DAY',
#  'day': 'DAY',
#  'HOUR': 'HOUR',
#  'hour': 'HOUR',
#  'MINUTE': 'MINUTE',
#  'minute': 'MINUTE',
#  'SECOND': 'SECOND',
#  'second': 'SECOND',
#  'DENS_CTD': 'DENS_CTD',
#  'dens_ctd': 'DENS_CTD',
#  'DENS_CTD [kg/m3]': 'DENS_CTD',
#  'dens_ctd [kg/m3]': 'DENS_CTD',
#  'Densitet': 'DENS_CTD',
#  'densitet': 'DENS_CTD',
#  'sigma-t00: Density [sigma-t, kg/m^3 ]': 'DENS_CTD',
#  'sigma-t00: density [sigma-t, kg/m^3 ]': 'DENS_CTD',
#  'sigma-t00: Density [sigma-t, Kg/m^3 ]': 'DENS_CTD',
#  'density00: Density [density, kg/m^3]': 'DENS_CTD',
#  'density00: density [density, kg/m^3]': 'DENS_CTD',
#  'SIGMA': 'DENS_CTD',
#  'sigma': 'DENS_CTD',
#  'SVEL_CTD': 'SVEL_CTD',
#  'svel_ctd': 'SVEL_CTD',
#  'SVEL_CTD [m/s]': 'SVEL_CTD',
#  'svel_ctd [m/s]': 'SVEL_CTD',
#  'Ljudhastighet': 'SVEL_CTD',
#  'ljudhastighet': 'SVEL_CTD',
#  'svCM: Sound Velocity [Chen-Millero, m/s]': 'SVEL_CTD',
#  'svcm: sound velocity [chen-millero, m/s]': 'SVEL_CTD',
#  'DEPH': 'DEPH',
#  'deph': 'DEPH',
#  'DEPH [m]': 'DEPH',
#  'deph [m]': 'DEPH',
#  'Djup': 'DEPH',
#  'djup': 'DEPH',
#  'depFM: Depth [true depth, m], lat': 'DEPH',
#  'depfm: depth [true depth, m], lat': 'DEPH',
#  'depFM: Depth [fresh water, m], lat': 'DEPH',
#  'depfm: depth [fresh water, m], lat': 'DEPH',
#  'FILE_NAME': 'FILE_NAME',
#  'file_name': 'FILE_NAME',
#  'FileName': 'FILE_NAME',
#  'filename': 'FILE_NAME',
#  'PAR_CTD': 'PAR_CTD',
#  'par_ctd': 'PAR_CTD',
#  'PAR_CTD [µmol/(m2 sec)]': 'PAR_CTD',
#  'par_ctd [µmol/(m2 sec)]': 'PAR_CTD',
#  'PAR_CTD [µE/(cm2 sec)]': 'PAR_CTD',
#  'par_ctd [µe/(cm2 sec)]': 'PAR_CTD',
#  'PAR_CTD [µE]': 'PAR_CTD',
#  'par_ctd [µe]': 'PAR_CTD',
#  'PAR': 'PAR_CTD',
#  'par': 'PAR_CTD',
#  'par: PAR/Irradiance, Biospherical/Licor': 'PAR_CTD',
#  'par: par/irradiance, biospherical/licor': 'PAR_CTD',
#  'par: PAR/Irradiance, Biospherical/Lico [ÂµE/(cm^2*s)]': 'PAR_CTD',
#  'par: par/irradiance, biospherical/lico [âµe/(cm^2*s)]': 'PAR_CTD',
#  'par: PAR/Irradiance, Biospherical/Lico [µE/(cm^2*s)]': 'PAR_CTD',
#  'par: par/irradiance, biospherical/lico [µe/(cm^2*s)]': 'PAR_CTD',
#  'LONGI': 'LONGI',
#  'longi': 'LONGI',
#  'NMEA Longitude': 'LONGI',
#  'nmea longitude': 'LONGI',
#  'Longitude [GG MM.mm E]': 'LONGI',
#  'longitude [gg mm.mm e]': 'LONGI',
#  'TEMP2_CTD': 'TEMP2_CTD',
#  'temp2_ctd': 'TEMP2_CTD',
#  'TEMP2_CTD [°C (ITS-90)]': 'TEMP2_CTD',
#  'temp2_ctd [°c (its-90)]': 'TEMP2_CTD',
#  'Temperatur2': 'TEMP2_CTD',
#  'temperatur2': 'TEMP2_CTD',
#  't190C: Temperature, 2 [ITS-90, deg C]': 'TEMP2_CTD',
#  't190c: temperature, 2 [its-90, deg c]': 'TEMP2_CTD',
#  'T_iS': 'TEMP2_CTD',
#  't_is': 'TEMP2_CTD',
#  'CHLFLUO_CTD': 'CHLFLUO_CTD',
#  'chlfluo_ctd': 'CHLFLUO_CTD',
#  'CHLFLUO_CTD [mg/m3]': 'CHLFLUO_CTD',
#  'chlfluo_ctd [mg/m3]': 'CHLFLUO_CTD',
#  'Klorofyllfluorescens': 'CHLFLUO_CTD',
#  'klorofyllfluorescens': 'CHLFLUO_CTD',
#  'haardtC: Fluorescence, Dr. Haardt Chlorophyll a': 'CHLFLUO_CTD',
#  'haardtc: fluorescence, dr. haardt chlorophyll a': 'CHLFLUO_CTD',
#  'chloroflTC0: Chlorophyll, Turner Cyclops [ug/l]': 'CHLFLUO_CTD',
#  'chlorofltc0: chlorophyll, turner cyclops [ug/l]': 'CHLFLUO_CTD',
#  'flECO-AFL: Chl-a Fluorescence, WET Labs ECO-AFL/FL [mg/m^3]': 'CHLFLUO_CTD',
#  'fleco-afl: chl-a fluorescence, wet labs eco-afl/fl [mg/m^3]': 'CHLFLUO_CTD',
#  'flECO-AFL: Fluorescence, WET Labs ECO-AFL/FL [mg/m^3]': 'CHLFLUO_CTD',
#  'fleco-afl: fluorescence, wet labs eco-afl/fl [mg/m^3]': 'CHLFLUO_CTD',
#  'PHYC_CTD': 'PHYC_CTD',
#  'phyc_ctd': 'PHYC_CTD',
#  'PHYC_CTD [ppb]': 'PHYC_CTD',
#  'phyc_ctd [ppb]': 'PHYC_CTD',
#  'Phycocyaninfluorescens': 'PHYC_CTD',
#  'phycocyaninfluorescens': 'PHYC_CTD',
#  'flECO-AFL1: Phycocyanin Fluorescence, WET Labs ECO-AFL/FL, 2 [mg/m^3]': 'PHYC_CTD',
#  'fleco-afl1: phycocyanin fluorescence, wet labs eco-afl/fl, 2 [mg/m^3]': 'PHYC_CTD',
#  'flECO-AFL1: Fluorescence, WET Labs ECO-AFL/FL, 2 [mg/m^3]': 'PHYC_CTD',
#  'fleco-afl1: fluorescence, wet labs eco-afl/fl, 2 [mg/m^3]': 'PHYC_CTD',
#  'SCAN_CTD': 'SCAN_CTD',
#  'scan_ctd': 'SCAN_CTD',
#  'SCAN_CTD []': 'SCAN_CTD',
#  'scan_ctd []': 'SCAN_CTD',
#  'scan nummer': 'SCAN_CTD',
#  'scan: Scan Count': 'SCAN_CTD',
#  'scan: scan count': 'SCAN_CTD',
#  'nbin: number of scans per bin': 'SCAN_BIN_CTD',
#  'DOXY2_CTD': 'DOXY2_CTD',
#  'doxy2_ctd': 'DOXY2_CTD',
#  'DOXY2_CTD [ml/l]': 'DOXY2_CTD',
#  'doxy2_ctd [ml/l]': 'DOXY2_CTD',
#  'Syrgashalt2': 'DOXY2_CTD',
#  'syrgashalt2': 'DOXY2_CTD',
#  'sbeox1ML/L: Oxygen, SBE 43, 2 [ml/l]': 'DOXY2_CTD',
#  'sbeox1ml/l: oxygen, sbe 43, 2 [ml/l]': 'DOXY2_CTD',
#  'sbeox1ML/L: Oxygen, SBE 43, 2 [ml/l], WS': 'DOXY2_CTD',
#  'sbeox1ml/l: oxygen, sbe 43, 2 [ml/l], ws': 'DOXY2_CTD',
#  'HUMUS_CTD': 'HUMUS_CTD',
#  'humus_ctd': 'HUMUS_CTD',
#  'Humus': 'HUMUS_CTD',
#  'humus': 'HUMUS_CTD',
#  'SPAR_CTD': 'SPAR_CTD',
#  'spar_ctd': 'SPAR_CTD',
#  'SPAR': 'SPAR_CTD',
#  'spar': 'SPAR_CTD',
#  'spar: SPAR/Surface Irradiance': 'SPAR_CTD',
#  'spar: spar/surface irradiance': 'SPAR_CTD',
#  'LATIT': 'LATIT',
#  'latit': 'LATIT',
#  'NMEA Latitude': 'LATIT',
#  'nmea latitude': 'LATIT',
#  'Latitude [GG MM.mm N]': 'LATIT',
#  'latitude [gg mm.mm n]': 'LATIT',
#  'SALT_CTD': 'SALT_CTD',
#  'salt_ctd': 'SALT_CTD',
#  'SALT_CTD [psu (PSS-78)]': 'SALT_CTD',
#  'salt_ctd [psu (pss-78)]': 'SALT_CTD',
#  'SALT_CTD [psu]': 'SALT_CTD',
#  'salt_ctd [psu]': 'SALT_CTD',
#  'Salthalt': 'SALT_CTD',
#  'salthalt': 'SALT_CTD',
#  'sal00: Salinity, Practical [PSU]': 'SALT_CTD',
#  'sal00: salinity, practical [psu]': 'SALT_CTD',
#  'SALIN': 'SALT_CTD',
#  'salin': 'SALT_CTD',
#  'SCAN_BIN_CTD': 'SCAN_BIN_CTD',
#  'scan_bin_ctd': 'SCAN_BIN_CTD',
#  'antal scans': 'SCAN_BIN_CTD',
#  'Datasets': 'SCAN_BIN_CTD',
#  'datasets': 'SCAN_BIN_CTD',
#  'INSTRUMENT_SERIE': 'INSTRUMENT_SERIE',
#  'instrument_serie': 'INSTRUMENT_SERIE',
#  'SERIAL NO': 'INSTRUMENT_SERIE',
#  'serial no': 'INSTRUMENT_SERIE',
#  'Q_FLAG': 'Q_FLAG',
#  'q_flag': 'Q_FLAG',
#  'flag: flag': 'Q_FLAG'}
