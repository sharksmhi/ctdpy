# %%
import sys
sys.path.append('C:/mw/git/sharkpylib')
sys.path.append('C:/mw/git/ctdpy')  #  

from ctdpy.core.session import Session
from ctdpy.core.utils import generate_filepaths, get_reversed_dictionary

from sharkpylib.qc.qc_default import QCBlueprint

import time
from pprint import pprint
# Out:
# WARNING! Could not add "C:/Utveckling/ctdvis" to sys.path.
# You should probably change path to the py-package "ctdvis" in settingsfile: C:\mw\git\ctdpy\pypaths.json
#
#
# WARNING! Could not add "C:/Utveckling/ctdpy" to sys.path.
# You should probably change path to the py-package "ctdpy" in settingsfile: C:\mw\git\ctdpy\pypaths.json
#
#
# WARNING! Could not add "C:/Utveckling/sharkpylib" to sys.path.
# You should probably change path to the py-package "sharkpylib" in settingsfile: C:\mw\git\ctdpy\pypaths.json
#
# Could not import pyodbc

# %%
###################        GET FILES        #################### 

# base_dir = 'C:\\Utveckling\\ctdpy\\ctdpy\\tests\\etc\\ctd_std_fmt_expedition_april_2020'
base_dir = r'C:\mw\data\dv_profile_standard'
# base_dir = 'C:\\Arbetsmapp\\datasets\\Profile\\2018\\SHARK_Profile_2018_BAS_SMHI\\processed_data'

files = generate_filepaths(base_dir,
                           endswith='.txt',                # Presumably CTD-standard format
                           only_from_dir=False,
                           )

# %%
###################        Create SESSION object        ###################

s = Session(filepaths=files,
            reader='ctd_stdfmt',
            )

# %%
###################        READ DELIVERY DATA, CNV, XLSX        ###################

start_time = time.time()

datasets = s.read()

print("Datasets loaded--%.3f sec" % (time.time() - start_time))
# Out:
# dataset txt
# Datasets loaded--2.197 sec

# %%
print('Files loaded:')
pprint(list(datasets[0]))
# Out:
# Files loaded:
# ['ctd_profile_20190116_7798_0001.txt',
#  'ctd_profile_20190121_77WX_0001.txt',
#  'ctd_profile_20190211_77WX_0006.txt',
#  'ctd_profile_20190214_7798_0002.txt',
#  'ctd_profile_20190304_77LA_0002.txt',
#  'ctd_profile_20190312_77FY_0001.txt',
#  'ctd_profile_20190312_77FY_0002.txt',
#  'ctd_profile_20190319_77LA_0007.txt',
#  'ctd_profile_20190321_7798_0003.txt',
#  'ctd_profile_20190325_77LA_0012.txt',
#  'ctd_profile_20190328_77FY_0003.txt',
#  'ctd_profile_20190401_77FY_0004.txt',
#  'ctd_profile_20190402_77LA_0017.txt',
#  'ctd_profile_20190410_77FY_0005.txt',
#  'ctd_profile_20190411_77LA_0022.txt',
#  'ctd_profile_20190415_77FY_0006.txt',
#  'ctd_profile_20190416_77LA_0027.txt',
#  'ctd_profile_20190423_77LA_0032.txt',
#  'ctd_profile_20190424_77FY_0007.txt',
#  'ctd_profile_20190425_7798_0004.txt',
#  'ctd_profile_20190506_77LA_0037.txt',
#  'ctd_profile_20190509_77FY_0008.txt',
#  'ctd_profile_20190509_77FY_0009.txt',
#  'ctd_profile_20190516_7798_0005.txt',
#  'ctd_profile_20190521_77FY_0096.txt',
#  'ctd_profile_20190522_77LA_0048.txt',
#  'ctd_profile_20190603_77LA_0056.txt',
#  'ctd_profile_20190604_77FY_0097.txt',
#  'ctd_profile_20190604_77FY_0098.txt',
#  'ctd_profile_20190614_7798_0006.txt',
#  'ctd_profile_20190617_77FY_0099.txt',
#  'ctd_profile_20190618_77LA_0062.txt',
#  'ctd_profile_20190703_77FY_0100.txt',
#  'ctd_profile_20190703_77FY_0101.txt',
#  'ctd_profile_20190704_77LA_0068.txt',
#  'ctd_profile_20190711_7798_0007.txt',
#  'ctd_profile_20190715_77FY_0102.txt',
#  'ctd_profile_20190716_77LA_0074.txt',
#  'ctd_profile_20190729_77LA_0081.txt',
#  'ctd_profile_20190731_77FY_0103.txt',
#  'ctd_profile_20190731_77FY_0104.txt',
#  'ctd_profile_20190812_77FY_0105.txt',
#  'ctd_profile_20190813_77LA_0087.txt',
#  'ctd_profile_20190822_7798_0008.txt',
#  'ctd_profile_20190826_77LA_0094.txt',
#  'ctd_profile_20190828_77FY_0106.txt',
#  'ctd_profile_20190828_77FY_0107.txt',
#  'ctd_profile_20190909_77FY_0108.txt',
#  'ctd_profile_20190910_77LA_0100.txt',
#  'ctd_profile_20190923_77LA_0106.txt',
#  'ctd_profile_20190924_7798_0009.txt',
#  'ctd_profile_20190925_77FY_0109.txt',
#  'ctd_profile_20190925_77FY_0110.txt',
#  'ctd_profile_20191007_77FY_0111.txt',
#  'ctd_profile_20191008_77LA_0109.txt',
#  'ctd_profile_20191022_77LA_0114.txt',
#  'ctd_profile_20191023_7798_0010.txt',
#  'ctd_profile_20191111_77LA_0119.txt',
#  'ctd_profile_20191113_7798_0011.txt',
#  'ctd_profile_20191209_77WX_0063.txt',
#  'ctd_profile_20191217_7798_0012.txt']

# %%
for data_key, item in datasets[0].items():
    break
print(type(data_key), data_key)
print(type(item), item.keys())
print(type(item['data']), type(item['metadata']))
# Out:
# <class 'str'> ctd_profile_20190116_7798_0001.txt
# <class 'dict'> dict_keys(['data', 'metadata'])
# <class 'pandas.core.frame.DataFrame'> <class 'pandas.core.series.Series'>

# %%
datasets[0].get('ctd_profile_20190116_7798_0001.txt')
# Out:
# {'data':      YEAR MONTH DAY HOUR MINUTE SECOND       CRUISE STATION LATITUDE_DD  \
#  0    2019    01  16   08     31     15  2019_7798_1      NR    60.13667
#  1    2019    01  16   08     31     17  2019_7798_1      NR    60.13667
#  2    2019    01  16   08     31     27  2019_7798_1      NR    60.13667
#  3    2019    01  16   08     31     56  2019_7798_1      NR    60.13667
#  4    2019    01  16   08     32     01  2019_7798_1      NR    60.13667
#  ..    ...   ...  ..  ...    ...    ...          ...     ...         ...
#  507  2019    01  16   09     53     06  2019_7798_1      NR    60.13667
#  508  2019    01  16   09     53     06  2019_7798_1      NR    60.13667
#  509  2019    01  16   09     53     12  2019_7798_1      NR    60.13667
#  510  2019    01  16   09     53     15  2019_7798_1      NR    60.13667
#  511  2019    01  16   09     53     27  2019_7798_1      NR    60.13667
#
#      LONGITUDE_DD  ... Q_DENS_CTD DOXY_CTD [ml/l] Q0_DOXY_CTD Q_DOXY_CTD  \
#  0       18.90833  ...          B           11.59       A0A0A
#  1       18.90833  ...          B           11.58       A0A0A
#  2       18.90833  ...                      10.81       A0A0A
#  3       18.90833  ...                       9.11       A0A0A
#  4       18.90833  ...                       9.13       A0A0A
#  ..           ...  ...        ...             ...         ...        ...
#  507     18.90833  ...                       6.23       A0A0A
#  508     18.90833  ...                       6.22       A0A0A
#  509     18.90833  ...                       6.23       A0A0A
#  510     18.90833  ...                       6.23       A0A0A
#  511     18.90833  ...                       6.20       A0A0A
#
#      DOXY_SAT_CTD [%] Q0_DOXY_SAT_CTD Q_DOXY_SAT_CTD PAR_CTD [µE] Q0_PAR_CTD  \
#  0             105.96           00000                       42.89      A0A00
#  1             105.90           00000                       39.83      A0A00
#  2             114.74           00000                       52.59      A0B00
#  3              97.81           00000                       13.28      A0A00
#  4              97.99           00000                       11.23      A0A00
#  ..               ...             ...            ...          ...        ...
#  507            73.73           00000                        2.04      A0A00
#  508            73.69           00000                        2.04      A0A00
#  509            73.71           00000                        2.04      A0A00
#  510            73.73           00000                        2.04      A0A00
#  511            73.44           00000                        2.04      A0A00
#
#      Q_PAR_CTD
#  0
#  1
#  2           B
#  3
#  4
#  ..        ...
#  507
#  508
#  509
#  510
#  511
#
#  [512 rows x 37 columns],
#  'metadata': 0                                      //FORMAT=PROFILE
#  1                                //METADATA_DELIMITER=;
#  2                                   //DATA_DELIMITER=\t
#  3                                 //METADATA;MYEAR;2019
#  4                                   //METADATA;PROJ;BAS
#                              ...
#  62    //INSTRUMENT_METADATA;; Datasets      IntD    ...
#  63    //INSTRUMENT_METADATA;;             [ Date]   ...
#  64                              //INSTRUMENT_METADATA;;
#  65    //COMNT_UNIT; UNIT CONVERSION PERFORMED BY a00...
#  66    //COMNT_QC; AUTOMATIC QC PERFORMED BY a002028;...
#  Length: 67, dtype: object}

# %%
##################        QUALITY CONTROL       ###################

start_time = time.time()

# This will produce alot of prints...

for data_key, item in datasets[0].items():
    # print(data_key)
    parameter_mapping = get_reversed_dictionary(s.settings.pmap, item['data'].keys())
    qc_run = QCBlueprint(item, parameter_mapping=parameter_mapping)
    qc_run()

print("QCBlueprint run--%.3f sec" % (time.time() - start_time))

# Auto QC performed. Q-flags inserted
# Out:
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# QC - USER: a001985
# QC-Decreasing failed for PAR_CTD [µE]
# QC-DataDiff failed for ['TEMP_CTD [°C]', 'TEMP2_CTD [°C]']
# QC-Range failed for TEMP_CTD [°C]
# QC-Range failed for TEMP2_CTD [°C]
# QC-Range failed for CNDC_CTD [S/m]
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# QC - USER: a001985
# QC-Decreasing failed for PAR_CTD [µE]
# QC-DataDiff failed for ['TEMP_CTD [°C]', 'TEMP2_CTD [°C]']
# QC-Range failed for TEMP_CTD [°C]
# QC-Range failed for TEMP2_CTD [°C]
# QC-Range failed for CNDC_CTD [S/m]
# QC-Range failed for DOXY_CTD [ml/l]
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu]
# QC-Spike failed for TEMP_CTD [°C]
# QC-Spike failed for TEMP2_CTD [°C]
# QC-Spike failed for DENS_CTD [kg/m3]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# QC - USER: a001985
# QC-Decreasing failed for PAR_CTD [µE]
# QC-DataDiff failed for ['TEMP_CTD [°C]', 'TEMP2_CTD [°C]']
# QC-Range failed for PRES_CTD [dbar]
# QC-Range failed for CNDC_CTD [S/m]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# QC - USER: a001985
# QC-Decreasing failed for PAR_CTD [µE]
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# QC-DataDiff failed for ['TEMP_CTD [°C]', 'TEMP2_CTD [°C]']
# QC-Range failed for CNDC_CTD [S/m]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# QC - USER: a001985
# QC-Decreasing failed for PAR_CTD [µE]
# QC-DataDiff failed for ['TEMP_CTD [°C]', 'TEMP2_CTD [°C]']
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# QC-Range failed for CNDC_CTD [S/m]
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu]
# QC-Spike failed for DENS_CTD [kg/m3]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# QC - USER: a001985
# QC-Decreasing failed for PAR_CTD [µE]
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# QC-DataDiff failed for ['TEMP_CTD [°C]', 'TEMP2_CTD [°C]']
# QC-Range failed for TEMP_CTD [°C]
# QC-Range failed for TEMP2_CTD [°C]
# QC-Range failed for CNDC_CTD [S/m]
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu]
# QC-Spike failed for TEMP_CTD [°C]
# QC-Spike failed for DENS_CTD [kg/m3]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# QC - USER: a001985
# QC-Decreasing failed for PAR_CTD [µE]
# QC-DataDiff failed for ['TEMP_CTD [°C]', 'TEMP2_CTD [°C]']
# QC-Range failed for CNDC_CTD [S/m]
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu]
# QC-Spike failed for TEMP_CTD [°C]
# QC-Spike failed for DENS_CTD [kg/m3]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# QC - USER: a001985
# QC-DataDiff failed for ['TEMP_CTD [°C]', 'TEMP2_CTD [°C]']
# QC-Range failed for CNDC_CTD [S/m]
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu]
# QC-Spike failed for TEMP_CTD [°C]
# QC-Spike failed for TEMP2_CTD [°C]
# QC-Spike failed for DENS_CTD [kg/m3]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# QC - USER: a001985
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# QC-DataDiff failed for ['TEMP_CTD [°C]', 'TEMP2_CTD [°C]']
# QC-Range failed for CNDC_CTD [S/m]
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu]
# QC-Spike failed for TEMP_CTD [°C]
# QC-Spike failed for TEMP2_CTD [°C]
# QC-Spike failed for DENS_CTD [kg/m3]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# QC - USER: a001985
# QC-Decreasing failed for PAR_CTD [µE]
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# QC-DataDiff failed for ['TEMP_CTD [°C]', 'TEMP2_CTD [°C]']
# QC-Range failed for PRES_CTD [dbar]
# QC-Range failed for CNDC_CTD [S/m]
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu]
# QC-Spike failed for TEMP_CTD [°C]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DOXY_CTD [ml/l]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# QC - USER: a001985
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# QC-Decreasing failed for PAR_CTD [µE]
# QC-DataDiff failed for ['TEMP_CTD [°C]', 'TEMP2_CTD [°C]']
# QC-Range failed for CNDC_CTD [S/m]
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu]
# QC-Spike failed for TEMP_CTD [°C]
# QC-Spike failed for TEMP2_CTD [°C]
# QC-Spike failed for DENS_CTD [kg/m3]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# QC - USER: a001985
# QC-Decreasing failed for PAR_CTD [µE]
# QC-DataDiff failed for ['TEMP_CTD [°C]', 'TEMP2_CTD [°C]']
# QC-Range failed for CNDC_CTD [S/m]
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu]
# QC-Spike failed for TEMP_CTD [°C]
# QC-Spike failed for DENS_CTD [kg/m3]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# QC - USER: a001985
# QC-Decreasing failed for PAR_CTD [µE]
# QC-DataDiff failed for ['TEMP_CTD [°C]', 'TEMP2_CTD [°C]']
# QC-Range failed for CNDC_CTD [S/m]
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu]
# QC-Spike failed for TEMP_CTD [°C]
# QC-Spike failed for TEMP2_CTD [°C]
# QC-Spike failed for DENS_CTD [kg/m3]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# QC - USER: a001985
# QC-DataDiff failed for ['TEMP_CTD [°C]', 'TEMP2_CTD [°C]']
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu]
# QC-Spike failed for TEMP_CTD [°C]
# QC-Spike failed for DENS_CTD [kg/m3]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# QC - USER: a001985
# QC-DataDiff failed for ['TEMP_CTD [°C]', 'TEMP2_CTD [°C]']
# QC-Range failed for CNDC_CTD [S/m]
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu]
# QC-Spike failed for TEMP_CTD [°C]
# QC-Spike failed for TEMP2_CTD [°C]
# QC-Spike failed for DENS_CTD [kg/m3]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# QC - USER: a001985
# QC-Decreasing failed for PAR_CTD [µE]
# QC-DataDiff failed for ['TEMP_CTD [°C]', 'TEMP2_CTD [°C]']
# QC-Range failed for CNDC_CTD [S/m]
# QC-Range failed for DOXY_CTD [ml/l]
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# QC-Range failed for DOXY_SAT_CTD [%]
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu]
# QC-Spike failed for TEMP_CTD [°C]
# QC-Spike failed for TEMP2_CTD [°C]
# QC-Spike failed for DENS_CTD [kg/m3]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# QC - USER: a001985
# QC-Range failed for CNDC_CTD [S/m]
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu]
# QC-Spike failed for DENS_CTD [kg/m3]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# QC - USER: a001985
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# QC-Decreasing failed for PAR_CTD [µE]
# QC-DataDiff failed for ['TEMP_CTD [°C]', 'TEMP2_CTD [°C]']
# QC-Range failed for CNDC_CTD [S/m]
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu]
# QC-Spike failed for TEMP_CTD [°C]
# QC-Spike failed for TEMP2_CTD [°C]
# QC-Spike failed for DENS_CTD [kg/m3]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# QC - USER: a001985
# QC-Decreasing failed for PAR_CTD [µE]
# QC-DataDiff failed for ['TEMP_CTD [°C]', 'TEMP2_CTD [°C]']
# QC-Range failed for CNDC_CTD [S/m]
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu]
# QC-Spike failed for TEMP_CTD [°C]
# QC-Spike failed for TEMP2_CTD [°C]
# QC-Spike failed for DENS_CTD [kg/m3]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# QC - USER: a001985
# QC-Decreasing failed for DOXY_CTD [ml/l]
# QC-Decreasing failed for PAR_CTD [µE]
# QC-DataDiff failed for ['TEMP_CTD [°C]', 'TEMP2_CTD [°C]']
# QC-Range failed for CNDC_CTD [S/m]
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu]
# QC-Spike failed for TEMP_CTD [°C]
# QC-Spike failed for TEMP2_CTD [°C]
# QC-Spike failed for DENS_CTD [kg/m3]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# QC - USER: a001985
# QC-Decreasing failed for DOXY_CTD [ml/l]
# QC-Decreasing failed for PAR_CTD [µE]
# QC-Range failed for CNDC_CTD [S/m]
# QC-Range failed for DOXY_CTD [ml/l]
# QC-Range failed for DOXY_SAT_CTD [%]
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu]
# QC-Spike failed for DENS_CTD [kg/m3]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# QC - USER: a001985
# QC-Decreasing failed for DOXY_CTD [ml/l]
# QC-Decreasing failed for PAR_CTD [µE]
# QC-Range failed for CNDC_CTD [S/m]
# QC-Range failed for DOXY_CTD [ml/l]
# QC-Range failed for DOXY_SAT_CTD [%]
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu]
# QC-Spike failed for TEMP_CTD [°C]
# QC-Spike failed for DENS_CTD [kg/m3]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# QC - USER: a001985
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# QC-Decreasing failed for DOXY_CTD [ml/l]
# QC-Range failed for CNDC_CTD [S/m]
# QC-Range failed for DOXY_CTD [ml/l]
# QC-Range failed for DOXY_SAT_CTD [%]
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu]
# QC-Spike failed for TEMP_CTD [°C]
# QC-Spike failed for DENS_CTD [kg/m3]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# ...
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# QC - USER: a001985
# QC-Decreasing failed for DOXY_CTD [ml/l]
# QC-Decreasing failed for PAR_CTD [µE]
# QC-Range failed for CNDC_CTD [S/m]
# QC-Range failed for DOXY_CTD [ml/l]
# QC-Range failed for DOXY_SAT_CTD [%]
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu]
# QC-Spike failed for TEMP_CTD [°C]
# QC-Spike failed for DENS_CTD [kg/m3]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# QC - USER: a001985
# QC-Decreasing failed for DOXY_CTD [ml/l]
# QC-Decreasing failed for PAR_CTD [µE]
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# QC-Range failed for CNDC_CTD [S/m]
# QC-Range failed for DOXY_CTD [ml/l]
# QC-Range failed for DOXY_SAT_CTD [%]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# QC - USER: a001985
# QC-Decreasing failed for DOXY_CTD [ml/l]
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# QC-Range failed for CNDC_CTD [S/m]
# QC-Range failed for DOXY_CTD [ml/l]
# QC-Range failed for DOXY_SAT_CTD [%]
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu]
# QC-Spike failed for TEMP_CTD [°C]
# QC-Spike failed for DENS_CTD [kg/m3]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# QC - USER: a001985
# QC-Decreasing failed for DOXY_CTD [ml/l]
# QC-Decreasing failed for PAR_CTD [µE]
# QC-Range failed for CNDC_CTD [S/m]
# QC-Range failed for DOXY_CTD [ml/l]
# QC-Range failed for DOXY_SAT_CTD [%]
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu]
# QC-Spike failed for TEMP_CTD [°C]
# QC-Spike failed for DENS_CTD [kg/m3]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# QC - USER: a001985
# QC-Decreasing failed for DOXY_CTD [ml/l]
# QC-Decreasing failed for PAR_CTD [µE]
# QC-Range failed for CNDC_CTD [S/m]
# QC-Range failed for DOXY_CTD [ml/l]
# QC-Range failed for DOXY_SAT_CTD [%]
# QC-Spike failed for TEMP_CTD [°C]
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# QC - USER: a001985
# QC-Decreasing failed for DOXY_CTD [ml/l]
# QC-Range failed for DOXY_CTD [ml/l]
# QC-Range failed for DOXY_SAT_CTD [%]
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu]
# QC-Spike failed for TEMP_CTD [°C]
# QC-Spike failed for DENS_CTD [kg/m3]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# QC - USER: a001985
# QC-Decreasing failed for DOXY_CTD [ml/l]
# QC-Decreasing failed for PAR_CTD [µE]
# QC-Range failed for CNDC_CTD [S/m]
# QC-Range failed for DOXY_CTD [ml/l]
# QC-Range failed for DOXY_SAT_CTD [%]
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu]
# QC-Spike failed for TEMP_CTD [°C]
# QC-Spike failed for DENS_CTD [kg/m3]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# QC - USER: a001985
# QC-Decreasing failed for DOXY_CTD [ml/l]
# QC-Range failed for PRES_CTD [dbar]
# QC-Range failed for CNDC_CTD [S/m]
# QC-Range failed for DOXY_CTD [ml/l]
# QC-Range failed for DOXY_SAT_CTD [%]
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# C:/mw/git/sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu]
# QC-Spike failed for TEMP_CTD [°C]
# QC-Spike failed for DENS_CTD [kg/m3]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q0_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q_DOXY_SAT_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# QC - USER: a001985
# QC-Decreasing failed for DOXY_CTD [ml/l]
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Range failed for CNDC_CTD [S/m]
# QC-Range failed for DOXY_CTD [ml/l]
# QC-Range failed for DOXY_SAT_CTD [%]
# QC-Spike failed for CNDC_CTD [S/m]
# QC-Spike failed for SALT_CTD [psu]
# QC-Spike failed for TEMP_CTD [°C]
# QC-Spike failed for DENS_CTD [kg/m3]
# QCBlueprint run--13.204 sec

# %%
first_ds = list(datasets[0])[0]

print('Note format of flagfield')
print(datasets[0][first_ds]['data']['Q0_TEMP_CTD'][:5])

print('\nDataframe from file: {}'.format(first_ds))
datasets[0][first_ds]['metadata']
# Out:
# Note format of flagfield
# 0    B00BA
# 1    B00BA
# 2    A00BA
# 3    A00AA
# 4    A00AA
# Name: Q0_TEMP_CTD, dtype: object
#
# Dataframe from file: ctd_profile_20190116_7798_0001.txt
# 0                                      //FORMAT=PROFILE
# 1                                //METADATA_DELIMITER=;
# 2                                   //DATA_DELIMITER=\t
# 3                                 //METADATA;MYEAR;2019
# 4                                   //METADATA;PROJ;BAS
#                             ...
# 63    //INSTRUMENT_METADATA;;             [ Date]   ...
# 64                              //INSTRUMENT_METADATA;;
# 65    //COMNT_UNIT; UNIT CONVERSION PERFORMED BY a00...
# 66    //COMNT_QC; AUTOMATIC QC PERFORMED BY a002028;...
# 68    //COMNT_QC; AUTOMATIC QC PERFORMED BY a001985;...
# Length: 68, dtype: object

# %%
#  ##################        UPDATE DATA ACCORDING TO CTD TEMPLATE (TXT-FORMAT)        ###################

# As of now we only export the updated ctd-datafile (ctd-standard-format). 
# delivery_note, metadata, sensorinfo, information are exclude.. (will be included..#TODO..)

start_time = time.time()
save_path = r'C:\mw\data\dv_profile_standard\export_ctdpy'
data_path = s.save_data(datasets, save_path=save_path, writer='ctd_standard_template', return_data_path=True)

print("Datasets saved--%.3f sec" % (time.time() - start_time))
# Out:
# Datasets saved--1.393 sec

# %%
s.settings.pmap
# Out:
# {'SALT2_CTD': 'SALT2_CTD',
#  'salt2_ctd': 'SALT2_CTD',
#  'SALT2_CTD [psu (PSS-78)]': 'SALT2_CTD',
#  'salt2_ctd [psu (pss-78)]': 'SALT2_CTD',
#  'Salthalt2': 'SALT2_CTD',
#  'salthalt2': 'SALT2_CTD',
#  'sal11: Salinity, Practical, 2 [PSU]': 'SALT2_CTD',
#  'sal11: salinity, practical, 2 [psu]': 'SALT2_CTD',
#  'DESC_RATE_CTD': 'DESC_RATE_CTD',
#  'desc_rate_ctd': 'DESC_RATE_CTD',
#  'DESC_RATE_CTD [m/s]': 'DESC_RATE_CTD',
#  'desc_rate_ctd [m/s]': 'DESC_RATE_CTD',
#  'fallhastighet': 'DESC_RATE_CTD',
#  'dz/dtM: Descent Rate [m/s], WS': 'DESC_RATE_CTD',
#  'dz/dtm: descent rate [m/s], ws': 'DESC_RATE_CTD',
#  'dz/dtM: Descent Rate [m/s]': 'DESC_RATE_CTD',
#  'dz/dtm: descent rate [m/s]': 'DESC_RATE_CTD',
#  'ALTM_CTD': 'ALTM_CTD',
#  'altm_ctd': 'ALTM_CTD',
#  'ALTM_CTD [m]': 'ALTM_CTD',
#  'altm_ctd [m]': 'ALTM_CTD',
#  'Altimeter': 'ALTM_CTD',
#  'altimeter': 'ALTM_CTD',
#  'altM: Altimeter [m]': 'ALTM_CTD',
#  'altm: altimeter [m]': 'ALTM_CTD',
#  'TEMP_CTD': 'TEMP_CTD',
#  'temp_ctd': 'TEMP_CTD',
#  'TEMP_CTD [°C (ITS-90)]': 'TEMP_CTD',
#  'temp_ctd [°c (its-90)]': 'TEMP_CTD',
#  'TEMP_CTD [°C]': 'TEMP_CTD',
#  'temp_ctd [°c]': 'TEMP_CTD',
#  'Temperatur': 'TEMP_CTD',
#  'temperatur': 'TEMP_CTD',
#  't090C: Temperature [ITS-90, deg C]': 'TEMP_CTD',
#  't090c: temperature [its-90, deg c]': 'TEMP_CTD',
#  'tv290C: Temperature [ITS-90, deg C]': 'TEMP_CTD',
#  'tv290c: temperature [its-90, deg c]': 'TEMP_CTD',
#  'Temperature [ITS-90, deg C]': 'TEMP_CTD',
#  'temperature [its-90, deg c]': 'TEMP_CTD',
#  'Temp': 'TEMP_CTD',
#  'temp': 'TEMP_CTD',
#  'CNDC2_CTD': 'CNDC2_CTD',
#  'cndc2_ctd': 'CNDC2_CTD',
#  'CNDC2_CTD [S/m]': 'CNDC2_CTD',
#  'cndc2_ctd [s/m]': 'CNDC2_CTD',
#  'Konduktivitet2': 'CNDC2_CTD',
#  'konduktivitet2': 'CNDC2_CTD',
#  'c1S/m: Conductivity, 2 [S/m]': 'CNDC2_CTD',
#  'c1s/m: conductivity, 2 [s/m]': 'CNDC2_CTD',
#  'DELTA_TEMP_CTD': 'DELTA_TEMP_CTD',
#  'delta_temp_ctd': 'DELTA_TEMP_CTD',
#  'temperatur delta': 'DELTA_TEMP_CTD',
#  'T2-T190C: Temperature Difference, 2 - 1 [ITS-90, deg C]': 'DELTA_TEMP_CTD',
#  't2-t190c: temperature difference, 2 - 1 [its-90, deg c]': 'DELTA_TEMP_CTD',
#  'YELLOW_CTD': 'YELLOW_CTD',
#  'yellow_ctd': 'YELLOW_CTD',
#  'Gulämne': 'YELLOW_CTD',
#  'gulämne': 'YELLOW_CTD',
#  'haardtY: Fluorescence, Dr. Haardt Yellow Sub': 'YELLOW_CTD',
#  'haardty: fluorescence, dr. haardt yellow sub': 'YELLOW_CTD',
#  'SVEL2_CTD': 'SVEL2_CTD',
#  'svel2_ctd': 'SVEL2_CTD',
#  'SVEL2_CTD [m/s]': 'SVEL2_CTD',
#  'svel2_ctd [m/s]': 'SVEL2_CTD',
#  'Ljudhastighet2': 'SVEL2_CTD',
#  'ljudhastighet2': 'SVEL2_CTD',
#  'svCM1: Sound Velocity, 2 [Chen-Millero, m/s]': 'SVEL2_CTD',
#  'svcm1: sound velocity, 2 [chen-millero, m/s]': 'SVEL2_CTD',
#  'DOXY_CTD': 'DOXY_CTD',
#  'doxy_ctd': 'DOXY_CTD',
#  'DOXY_CTD [ml/l]': 'DOXY_CTD',
#  'doxy_ctd [ml/l]': 'DOXY_CTD',
#  'Syrgashalt': 'DOXY_CTD',
#  'syrgashalt': 'DOXY_CTD',
#  'sbeox0ML/L: Oxygen, SBE 43 [ml/l]': 'DOXY_CTD',
#  'sbeox0ml/l: oxygen, sbe 43 [ml/l]': 'DOXY_CTD',
#  'sbeox0ML/L: Oxygen, SBE 43 [ml/l], WS': 'DOXY_CTD',
#  'sbeox0ml/l: oxygen, sbe 43 [ml/l], ws': 'DOXY_CTD',
#  'sbeox0ML/L: Oxygen [ml/l], WS': 'DOXY_CTD',
#  'sbeox0ml/l: oxygen [ml/l], ws': 'DOXY_CTD',
#  'sbeox0ML/L: Oxygen, [ml/l], WS = 2': 'DOXY_CTD',
#  'sbeox0ml/l: oxygen, [ml/l], ws = 2': 'DOXY_CTD',
#  'DO_ml': 'DOXY_CTD',
#  'do_ml': 'DOXY_CTD',
#  'DOXY_SAT_CTD': 'DOXY_SAT_CTD',
#  'doxy_sat_ctd': 'DOXY_SAT_CTD',
#  'DO': 'DOXY_SAT_CTD',
#  'do': 'DOXY_SAT_CTD',
#  'sat': 'DOXY_SAT_CTD',
#  'PUMP_CTD': 'PUMP_CTD',
#  'pump_ctd': 'PUMP_CTD',
#  'PUMP_CTD []': 'PUMP_CTD',
#  'pump_ctd []': 'PUMP_CTD',
#  'pump status': 'PUMP_CTD',
#  'pumps: Pump Status': 'PUMP_CTD',
#  'pumps: pump status': 'PUMP_CTD',
#  'DENS2_CTD': 'DENS2_CTD',
#  'dens2_ctd': 'DENS2_CTD',
#  'DENS2_CTD [kg/m3]': 'DENS2_CTD',
#  'dens2_ctd [kg/m3]': 'DENS2_CTD',
#  'Densitet2': 'DENS2_CTD',
#  'densitet2': 'DENS2_CTD',
#  'sigma-t11: Density, 2 [sigma-t, Kg/m^3 ]': 'DENS2_CTD',
#  'sigma-t11: density, 2 [sigma-t, kg/m^3 ]': 'DENS2_CTD',
#  'CNDC_CTD': 'CNDC_CTD',
#  'cndc_ctd': 'CNDC_CTD',
#  'CNDC_CTD [S/m]': 'CNDC_CTD',
#  'cndc_ctd [s/m]': 'CNDC_CTD',
#  'CNDC_CTD [mS/cm]': 'CNDC_CTD',
#  'cndc_ctd [ms/cm]': 'CNDC_CTD',
#  'Konduktivitet': 'CNDC_CTD',
#  'konduktivitet': 'CNDC_CTD',
#  'c0S/m: Conductivity [S/m]': 'CNDC_CTD',
#  'c0s/m: conductivity [s/m]': 'CNDC_CTD',
#  'Cond': 'CNDC_CTD',
#  'cond': 'CNDC_CTD',
#  'TURB_CTD': 'TURB_CTD',
#  'turb_ctd': 'TURB_CTD',
#  'TURB_CTD [NTU]': 'TURB_CTD',
#  'turb_ctd [ntu]': 'TURB_CTD',
#  'Turbiditet': 'TURB_CTD',
#  'turbiditet': 'TURB_CTD',
#  'turbWETntu0: Turbidity, WET Labs ECO [NTU]': 'TURB_CTD',
#  'turbwetntu0: turbidity, wet labs eco [ntu]': 'TURB_CTD',
#  'CRUISE_NO': 'CRUISE_NO',
#  'cruise_no': 'CRUISE_NO',
#  'Cruise': 'CRUISE_NO',
#  'cruise': 'CRUISE_NO',
#  'STATN': 'STATN',
#  'statn': 'STATN',
#  'Station': 'STATN',
#  'station': 'STATN',
#  'SHIPC': 'SHIPC',
#  'shipc': 'SHIPC',
#  'Ship': 'SHIPC',
#  'ship': 'SHIPC',
#  'SERNO': 'SERNO',
#  'serno': 'SERNO',
#  'LIMS Job': 'SERNO',
#  'lims job': 'SERNO',
#  'PRES_CTD': 'PRES_CTD',
#  'pres_ctd': 'PRES_CTD',
#  'PRES_CTD [dbar]': 'PRES_CTD',
#  'pres_ctd [dbar]': 'PRES_CTD',
#  'Tryck': 'PRES_CTD',
#  'tryck': 'PRES_CTD',
#  'prDM: Pressure, Digiquartz [db]': 'PRES_CTD',
#  'prdm: pressure, digiquartz [db]': 'PRES_CTD',
#  'Pressure, Strain Gauge [db]': 'PRES_CTD',
#  'pressure, strain gauge [db]': 'PRES_CTD',
#  'prdM: Pressure, Strain Gauge [db]': 'PRES_CTD',
#  'prdm: pressure, strain gauge [db]': 'PRES_CTD',
#  'Press': 'PRES_CTD',
#  'press': 'PRES_CTD',
#  'SDATE': 'SDATE',
#  'sdate': 'SDATE',
#  'NMEA UTC': 'SDATE',
#  'nmea utc': 'SDATE',
#  'System UTC': 'SDATE',
#  'system utc': 'SDATE',
#  'start_time': 'SDATE',
#  'IntD': 'SDATE',
#  'intd': 'SDATE',
#  'STIME': 'STIME',
#  'stime': 'STIME',
#  'IntT': 'STIME',
#  'intt': 'STIME',
#  'YEAR': 'YEAR',
#  'year': 'YEAR',
#  'MONTH': 'MONTH',
#  'month': 'MONTH',
#  'DAY': 'DAY',
#  'day': 'DAY',
#  'HOUR': 'HOUR',
#  'hour': 'HOUR',
#  'MINUTE': 'MINUTE',
#  'minute': 'MINUTE',
#  'SECOND': 'SECOND',
#  'second': 'SECOND',
#  'DENS_CTD': 'DENS_CTD',
#  'dens_ctd': 'DENS_CTD',
#  'DENS_CTD [kg/m3]': 'DENS_CTD',
#  'dens_ctd [kg/m3]': 'DENS_CTD',
#  'Densitet': 'DENS_CTD',
#  'densitet': 'DENS_CTD',
#  'sigma-t00: Density [sigma-t, kg/m^3 ]': 'DENS_CTD',
#  'sigma-t00: density [sigma-t, kg/m^3 ]': 'DENS_CTD',
#  'sigma-t00: Density [sigma-t, Kg/m^3 ]': 'DENS_CTD',
#  'density00: Density [density, kg/m^3]': 'DENS_CTD',
#  'density00: density [density, kg/m^3]': 'DENS_CTD',
#  'SIGMA': 'DENS_CTD',
#  'sigma': 'DENS_CTD',
#  'SVEL_CTD': 'SVEL_CTD',
#  'svel_ctd': 'SVEL_CTD',
#  'SVEL_CTD [m/s]': 'SVEL_CTD',
#  'svel_ctd [m/s]': 'SVEL_CTD',
#  'Ljudhastighet': 'SVEL_CTD',
#  'ljudhastighet': 'SVEL_CTD',
#  'svCM: Sound Velocity [Chen-Millero, m/s]': 'SVEL_CTD',
#  'svcm: sound velocity [chen-millero, m/s]': 'SVEL_CTD',
#  'DEPH': 'DEPH',
#  'deph': 'DEPH',
#  'DEPH [m]': 'DEPH',
#  'deph [m]': 'DEPH',
#  'Djup': 'DEPH',
#  'djup': 'DEPH',
#  'depFM: Depth [true depth, m], lat': 'DEPH',
#  'depfm: depth [true depth, m], lat': 'DEPH',
#  'depFM: Depth [fresh water, m], lat': 'DEPH',
#  'depfm: depth [fresh water, m], lat': 'DEPH',
#  'FILE_NAME': 'FILE_NAME',
#  'file_name': 'FILE_NAME',
#  'FileName': 'FILE_NAME',
#  'filename': 'FILE_NAME',
#  'PAR_CTD': 'PAR_CTD',
#  'par_ctd': 'PAR_CTD',
#  'PAR_CTD [µmol/(m2 sec)]': 'PAR_CTD',
#  'par_ctd [µmol/(m2 sec)]': 'PAR_CTD',
#  'PAR_CTD [µE/(cm2 sec)]': 'PAR_CTD',
#  'par_ctd [µe/(cm2 sec)]': 'PAR_CTD',
#  'PAR_CTD [µE]': 'PAR_CTD',
#  'par_ctd [µe]': 'PAR_CTD',
#  'PAR': 'PAR_CTD',
#  'par': 'PAR_CTD',
#  'par: PAR/Irradiance, Biospherical/Licor': 'PAR_CTD',
#  'par: par/irradiance, biospherical/licor': 'PAR_CTD',
#  'par: PAR/Irradiance, Biospherical/Lico [ÂµE/(cm^2*s)]': 'PAR_CTD',
#  'par: par/irradiance, biospherical/lico [âµe/(cm^2*s)]': 'PAR_CTD',
#  'par: PAR/Irradiance, Biospherical/Lico [µE/(cm^2*s)]': 'PAR_CTD',
#  'par: par/irradiance, biospherical/lico [µe/(cm^2*s)]': 'PAR_CTD',
#  'LONGI': 'LONGI',
#  'longi': 'LONGI',
#  'NMEA Longitude': 'LONGI',
#  'nmea longitude': 'LONGI',
#  'Longitude [GG MM.mm E]': 'LONGI',
#  'longitude [gg mm.mm e]': 'LONGI',
#  'TEMP2_CTD': 'TEMP2_CTD',
#  'temp2_ctd': 'TEMP2_CTD',
#  'TEMP2_CTD [°C (ITS-90)]': 'TEMP2_CTD',
#  'temp2_ctd [°c (its-90)]': 'TEMP2_CTD',
#  'Temperatur2': 'TEMP2_CTD',
#  'temperatur2': 'TEMP2_CTD',
#  't190C: Temperature, 2 [ITS-90, deg C]': 'TEMP2_CTD',
#  't190c: temperature, 2 [its-90, deg c]': 'TEMP2_CTD',
#  'T_iS': 'TEMP2_CTD',
#  't_is': 'TEMP2_CTD',
#  'CHLFLUO_CTD': 'CHLFLUO_CTD',
#  'chlfluo_ctd': 'CHLFLUO_CTD',
#  'CHLFLUO_CTD [mg/m3]': 'CHLFLUO_CTD',
#  'chlfluo_ctd [mg/m3]': 'CHLFLUO_CTD',
#  'Klorofyllfluorescens': 'CHLFLUO_CTD',
#  'klorofyllfluorescens': 'CHLFLUO_CTD',
#  'haardtC: Fluorescence, Dr. Haardt Chlorophyll a': 'CHLFLUO_CTD',
#  'haardtc: fluorescence, dr. haardt chlorophyll a': 'CHLFLUO_CTD',
#  'chloroflTC0: Chlorophyll, Turner Cyclops [ug/l]': 'CHLFLUO_CTD',
#  'chlorofltc0: chlorophyll, turner cyclops [ug/l]': 'CHLFLUO_CTD',
#  'flECO-AFL: Chl-a Fluorescence, WET Labs ECO-AFL/FL [mg/m^3]': 'CHLFLUO_CTD',
#  'fleco-afl: chl-a fluorescence, wet labs eco-afl/fl [mg/m^3]': 'CHLFLUO_CTD',
#  'flECO-AFL: Fluorescence, WET Labs ECO-AFL/FL [mg/m^3]': 'CHLFLUO_CTD',
#  'fleco-afl: fluorescence, wet labs eco-afl/fl [mg/m^3]': 'CHLFLUO_CTD',
#  'PHYC_CTD': 'PHYC_CTD',
#  'phyc_ctd': 'PHYC_CTD',
#  'PHYC_CTD [ppb]': 'PHYC_CTD',
#  'phyc_ctd [ppb]': 'PHYC_CTD',
#  'Phycocyaninfluorescens': 'PHYC_CTD',
#  'phycocyaninfluorescens': 'PHYC_CTD',
#  'flECO-AFL1: Phycocyanin Fluorescence, WET Labs ECO-AFL/FL, 2 [mg/m^3]': 'PHYC_CTD',
#  'fleco-afl1: phycocyanin fluorescence, wet labs eco-afl/fl, 2 [mg/m^3]': 'PHYC_CTD',
#  'flECO-AFL1: Fluorescence, WET Labs ECO-AFL/FL, 2 [mg/m^3]': 'PHYC_CTD',
#  'fleco-afl1: fluorescence, wet labs eco-afl/fl, 2 [mg/m^3]': 'PHYC_CTD',
#  'SCAN_CTD': 'SCAN_CTD',
#  'scan_ctd': 'SCAN_CTD',
#  'SCAN_CTD []': 'SCAN_CTD',
#  'scan_ctd []': 'SCAN_CTD',
#  'scan nummer': 'SCAN_CTD',
#  'scan: Scan Count': 'SCAN_CTD',
#  'scan: scan count': 'SCAN_CTD',
#  'nbin: number of scans per bin': 'SCAN_BIN_CTD',
#  'DOXY2_CTD': 'DOXY2_CTD',
#  'doxy2_ctd': 'DOXY2_CTD',
#  'DOXY2_CTD [ml/l]': 'DOXY2_CTD',
#  'doxy2_ctd [ml/l]': 'DOXY2_CTD',
#  'Syrgashalt2': 'DOXY2_CTD',
#  'syrgashalt2': 'DOXY2_CTD',
#  'sbeox1ML/L: Oxygen, SBE 43, 2 [ml/l]': 'DOXY2_CTD',
#  'sbeox1ml/l: oxygen, sbe 43, 2 [ml/l]': 'DOXY2_CTD',
#  'sbeox1ML/L: Oxygen, SBE 43, 2 [ml/l], WS': 'DOXY2_CTD',
#  'sbeox1ml/l: oxygen, sbe 43, 2 [ml/l], ws': 'DOXY2_CTD',
#  'HUMUS_CTD': 'HUMUS_CTD',
#  'humus_ctd': 'HUMUS_CTD',
#  'Humus': 'HUMUS_CTD',
#  'humus': 'HUMUS_CTD',
#  'SPAR_CTD': 'SPAR_CTD',
#  'spar_ctd': 'SPAR_CTD',
#  'SPAR': 'SPAR_CTD',
#  'spar': 'SPAR_CTD',
#  'spar: SPAR/Surface Irradiance': 'SPAR_CTD',
#  'spar: spar/surface irradiance': 'SPAR_CTD',
#  'LATIT': 'LATIT',
#  'latit': 'LATIT',
#  'NMEA Latitude': 'LATIT',
#  'nmea latitude': 'LATIT',
#  'Latitude [GG MM.mm N]': 'LATIT',
#  'latitude [gg mm.mm n]': 'LATIT',
#  'SALT_CTD': 'SALT_CTD',
#  'salt_ctd': 'SALT_CTD',
#  'SALT_CTD [psu (PSS-78)]': 'SALT_CTD',
#  'salt_ctd [psu (pss-78)]': 'SALT_CTD',
#  'SALT_CTD [psu]': 'SALT_CTD',
#  'salt_ctd [psu]': 'SALT_CTD',
#  'Salthalt': 'SALT_CTD',
#  'salthalt': 'SALT_CTD',
#  'sal00: Salinity, Practical [PSU]': 'SALT_CTD',
#  'sal00: salinity, practical [psu]': 'SALT_CTD',
#  'SALIN': 'SALT_CTD',
#  'salin': 'SALT_CTD',
#  'SCAN_BIN_CTD': 'SCAN_BIN_CTD',
#  'scan_bin_ctd': 'SCAN_BIN_CTD',
#  'antal scans': 'SCAN_BIN_CTD',
#  'Datasets': 'SCAN_BIN_CTD',
#  'datasets': 'SCAN_BIN_CTD',
#  'INSTRUMENT_SERIE': 'INSTRUMENT_SERIE',
#  'instrument_serie': 'INSTRUMENT_SERIE',
#  'SERIAL NO': 'INSTRUMENT_SERIE',
#  'serial no': 'INSTRUMENT_SERIE',
#  'Q_FLAG': 'Q_FLAG',
#  'q_flag': 'Q_FLAG',
#  'flag: flag': 'Q_FLAG'}
