# %%
import sys
sys.path.append('C:\\Utveckling\\sharkpylib')
sys.path.append('C:\\Utveckling\\ctdpy')  #  

from ctdpy.core.session import Session
from ctdpy.core.utils import generate_filepaths, get_reversed_dictionary

from sharkpylib.qc.qc_default import QCBlueprint

import time
from pprint import pprint

# %%
###################        GET FILES        #################### 

# base_dir = 'C:\\Utveckling\\ctdpy\\ctdpy\\tests\\etc\\ctd_std_fmt_expedition_april_2020'
base_dir = 'C:\\Temp\\CTD_DV\\ctd_std_fmt_20200526_095058'

files = generate_filepaths(base_dir,
                           endswith='.txt',                # Presumably CTD-standard format
                           only_from_dir=False,
                           )

# %%
###################        Create SESSION object        ###################

s = Session(filepaths=files,
            reader='ctd_stdfmt',
            )

# %%
###################        READ DELIVERY DATA, CNV, XLSX        ###################

start_time = time.time()

datasets = s.read()

print("Datasets loaded--%.3f sec" % (time.time() - start_time))
# Out:
# dataset txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200508_77SE_0383.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200508_77SE_0384.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200508_77SE_0385.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200508_77SE_0386.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200509_77SE_0387.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200509_77SE_0388.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200509_77SE_0389.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200509_77SE_0390.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200510_77SE_0391.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200510_77SE_0392.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200510_77SE_0393.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200511_77SE_0394.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200511_77SE_0395.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200511_77SE_0396.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200511_77SE_0397.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200512_77SE_0398.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200512_77SE_0399.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200512_77SE_0400.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200512_77SE_0401.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200512_77SE_0402.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200512_77SE_0403.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200512_77SE_0404.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200512_77SE_0405.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200513_77SE_0406.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200513_77SE_0407.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200514_77SE_0408.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200514_77SE_0409.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200514_77SE_0410.txt
# Loading text file: C:\Temp\CTD_DV\ctd_std_fmt_20200526_095058\ctd_profile_20200514_77SE_0411.txt
# Datasets loaded--0.523 sec

# %%
print('Files loaded:')
pprint(list(datasets[0]))
# Out:
# Files loaded:
# ['ctd_profile_20200508_77SE_0383.txt',
#  'ctd_profile_20200508_77SE_0384.txt',
#  'ctd_profile_20200508_77SE_0385.txt',
#  'ctd_profile_20200508_77SE_0386.txt',
#  'ctd_profile_20200509_77SE_0387.txt',
#  'ctd_profile_20200509_77SE_0388.txt',
#  'ctd_profile_20200509_77SE_0389.txt',
#  'ctd_profile_20200509_77SE_0390.txt',
#  'ctd_profile_20200510_77SE_0391.txt',
#  'ctd_profile_20200510_77SE_0392.txt',
#  'ctd_profile_20200510_77SE_0393.txt',
#  'ctd_profile_20200511_77SE_0394.txt',
#  'ctd_profile_20200511_77SE_0395.txt',
#  'ctd_profile_20200511_77SE_0396.txt',
#  'ctd_profile_20200511_77SE_0397.txt',
#  'ctd_profile_20200512_77SE_0398.txt',
#  'ctd_profile_20200512_77SE_0399.txt',
#  'ctd_profile_20200512_77SE_0400.txt',
#  'ctd_profile_20200512_77SE_0401.txt',
#  'ctd_profile_20200512_77SE_0402.txt',
#  'ctd_profile_20200512_77SE_0403.txt',
#  'ctd_profile_20200512_77SE_0404.txt',
#  'ctd_profile_20200512_77SE_0405.txt',
#  'ctd_profile_20200513_77SE_0406.txt',
#  'ctd_profile_20200513_77SE_0407.txt',
#  'ctd_profile_20200514_77SE_0408.txt',
#  'ctd_profile_20200514_77SE_0409.txt',
#  'ctd_profile_20200514_77SE_0410.txt',
#  'ctd_profile_20200514_77SE_0411.txt']

# %%
##################        QUALITY CONTROL       ###################

start_time = time.time()

# This will produce alot of prints...

for data_key, item in datasets[0].items():
    # print(data_key)
    parameter_mapping = get_reversed_dictionary(s.settings.pmap, item['data'].keys())
    qc_run = QCBlueprint(item, parameter_mapping=parameter_mapping)
    qc_run()

print("QCBlueprint run--%.3f sec" % (time.time() - start_time))

# Auto QC performed. Q-flags inserted
# Out:
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# C:\Utveckling\sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-Decreasing failed for DOXY_CTD [ml/l]
# QC-Decreasing failed for DOXY2_CTD [ml/l]
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for DOXY_CTD [ml/l]
# QC-Range failed for DOXY2_CTD [ml/l]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-Decreasing failed for PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-DataDiff failed for ['TEMP_CTD [°C (ITS-90)]', 'TEMP2_CTD [°C (ITS-90)]']
# QC-Range failed for DOXY2_CTD [ml/l]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Range failed for TURB_CTD [NTU]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-DataDiff failed for ['DOXY_CTD [ml/l]', 'DOXY2_CTD [ml/l]']
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q0_PHYC_CTD
# ...
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-Decreasing failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for TURB_CTD [NTU]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-Decreasing failed for PAR_CTD [µE/(cm2 sec)]
# QC-Increasing failed for DENS_CTD [kg/m3]
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for SALT_CTD [psu (PSS-78)]
# QC-Spike failed for SALT2_CTD [psu (PSS-78)]
# QC-Spike failed for DENS_CTD [kg/m3]
# QC-Spike failed for DENS2_CTD [kg/m3]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for DOXY2_CTD [ml/l]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-Decreasing failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for DOXY_CTD [ml/l]
# QC-Spike failed for PHYC_CTD [ppb]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-Range failed for PAR_CTD [µE/(cm2 sec)]
# QC-Spike failed for CHLFLUO_CTD [mg/m3]
# QC-Spike failed for PHYC_CTD [ppb]
# QCBlueprint run--5.688 sec

# %%
first_ds = list(datasets[0])[0]

print('Note format of flagfield')
print(datasets[0][first_ds]['data']['Q0_TEMP_CTD'][:5])

print('\nDataframe from file: {}'.format(first_ds))
datasets[0][first_ds]['metadata'][760]
# Out:
# Note format of flagfield
# 0    A00AA
# 1    A00AA
# 2    A00AA
# 3    A00AA
# 4    A00AA
# Name: Q0_TEMP_CTD, dtype: object
#
# Dataframe from file: ctd_profile_20200508_77SE_0383.txt
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-313e00baaeb1> in <module>
#       5
#       6 print('\nDataframe from file: {}'.format(first_ds))
# ----> 7 datasets[0][first_ds]['metadata'][760]
#
# C:\Continuum\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# C:\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 760

# %%
#  ##################        UPDATE DATA ACCORDING TO CTD TEMPLATE (TXT-FORMAT)        ###################

# As of now we only export the updated ctd-datafile (ctd-standard-format). 
# delivery_note, metadata, sensorinfo, information are exclude.. (will be included..#TODO..)

start_time = time.time()

data_path = s.save_data(datasets, writer='ctd_standard_template', return_data_path=True)

print("Datasets saved--%.3f sec" % (time.time() - start_time))

# %%
s.settings.pmap
