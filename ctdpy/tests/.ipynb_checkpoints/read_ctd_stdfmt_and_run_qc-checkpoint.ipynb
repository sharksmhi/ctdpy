# %%
import sys
sys.path.append('C:\\Utveckling\\sharkpylib')
sys.path.append('C:\\Utveckling\\ctdpy')  #  

from ctdpy.core.session import Session
from ctdpy.core.utils import generate_filepaths, get_reversed_dictionary

from sharkpylib.qc.qc_default import QCBlueprint

import time
from pprint import pprint

# %%
###################        GET FILES        #################### 

base_dir = 'C:\\Utveckling\\ctdpy\\ctdpy\\tests\\etc\\ctd_std_fmt_expedition_april_2020'

files = generate_filepaths(base_dir,
                           endswith='.txt',                # Presumably CTD-standard format
                           only_from_dir=False,
                           )

# %%
###################        Create SESSION object        ###################

s = Session(filepaths=files,
            reader='ctd_stdfmt',
            )
# Out:
# C:\Utveckling\ctdpy\ctdpy\core\readers\yaml_reader.py:46: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)

# %%
###################        READ DELIVERY DATA, CNV, XLSX        ###################

start_time = time.time()

datasets = s.read()

print("Datasets loaded--%.3f sec" % (time.time() - start_time))
# Out:
# dataset txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_expedition_april_2020\ctd_profile_20200414_77SE_0336.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_expedition_april_2020\ctd_profile_20200414_77SE_0337.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_expedition_april_2020\ctd_profile_20200414_77SE_0338.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_expedition_april_2020\ctd_profile_20200414_77SE_0339.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_expedition_april_2020\ctd_profile_20200414_77SE_0340.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_expedition_april_2020\ctd_profile_20200414_77SE_0341.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_expedition_april_2020\ctd_profile_20200415_77SE_0342.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_expedition_april_2020\ctd_profile_20200415_77SE_0343.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_expedition_april_2020\ctd_profile_20200415_77SE_0344.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_expedition_april_2020\ctd_profile_20200415_77SE_0345.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_expedition_april_2020\ctd_profile_20200415_77SE_0346.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_expedition_april_2020\ctd_profile_20200416_77SE_0347.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_expedition_april_2020\ctd_profile_20200416_77SE_0348.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_expedition_april_2020\ctd_profile_20200416_77SE_0349.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_expedition_april_2020\ctd_profile_20200416_77SE_0350.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_expedition_april_2020\ctd_profile_20200416_77SE_0351.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_expedition_april_2020\ctd_profile_20200417_77SE_0352.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_expedition_april_2020\ctd_profile_20200417_77SE_0353.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_expedition_april_2020\ctd_profile_20200417_77SE_0354.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_expedition_april_2020\ctd_profile_20200418_77SE_0355.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_expedition_april_2020\ctd_profile_20200418_77SE_0356.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_expedition_april_2020\ctd_profile_20200418_77SE_0357.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_expedition_april_2020\ctd_profile_20200418_77SE_0358.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_expedition_april_2020\ctd_profile_20200419_77SE_0359.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_expedition_april_2020\ctd_profile_20200419_77SE_0360.txt
# Datasets loaded--0.417 sec

# %%
print('Files loaded:')
pprint(list(datasets[0]))
# Out:
# Files loaded:
# ['ctd_profile_20200414_77SE_0336.txt',
#  'ctd_profile_20200414_77SE_0337.txt',
#  'ctd_profile_20200414_77SE_0338.txt',
#  'ctd_profile_20200414_77SE_0339.txt',
#  'ctd_profile_20200414_77SE_0340.txt',
#  'ctd_profile_20200414_77SE_0341.txt',
#  'ctd_profile_20200415_77SE_0342.txt',
#  'ctd_profile_20200415_77SE_0343.txt',
#  'ctd_profile_20200415_77SE_0344.txt',
#  'ctd_profile_20200415_77SE_0345.txt',
#  'ctd_profile_20200415_77SE_0346.txt',
#  'ctd_profile_20200416_77SE_0347.txt',
#  'ctd_profile_20200416_77SE_0348.txt',
#  'ctd_profile_20200416_77SE_0349.txt',
#  'ctd_profile_20200416_77SE_0350.txt',
#  'ctd_profile_20200416_77SE_0351.txt',
#  'ctd_profile_20200417_77SE_0352.txt',
#  'ctd_profile_20200417_77SE_0353.txt',
#  'ctd_profile_20200417_77SE_0354.txt',
#  'ctd_profile_20200418_77SE_0355.txt',
#  'ctd_profile_20200418_77SE_0356.txt',
#  'ctd_profile_20200418_77SE_0357.txt',
#  'ctd_profile_20200418_77SE_0358.txt',
#  'ctd_profile_20200419_77SE_0359.txt',
#  'ctd_profile_20200419_77SE_0360.txt']

# %%
##################        QUALITY CONTROL       ###################

start_time = time.time()

# This will produce alot of prints...

for data_key, item in datasets[0].items():
    # print(data_key)
    parameter_mapping = get_reversed_dictionary(s.settings.pmap, item['data'].keys())
    qc_run = QCBlueprint(item, parameter_mapping=parameter_mapping)
    qc_run()

print("QCBlueprint run--%.3f sec" % (time.time() - start_time))

# Auto QC performed. Q-flags inserted
# Out:
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: SCAN_CTD []
# No mapping found for key: SCAN_CTD []
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: PUMP_CTD []
# No mapping found for key: PUMP_CTD []
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-Spike failed for DEPH [m]
# QC-Spike failed for PRES_CTD [dbar]
# C:\Utveckling\sharkpylib\sharkpylib\file\yaml_reader.py:31: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   file = yaml.load(fd)
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: SCAN_CTD []
# No mapping found for key: SCAN_CTD []
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: PUMP_CTD []
# No mapping found for key: PUMP_CTD []
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-Spike failed for DEPH [m]
# QC-Spike failed for PRES_CTD [dbar]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: SCAN_CTD []
# No mapping found for key: SCAN_CTD []
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: PUMP_CTD []
# No mapping found for key: PUMP_CTD []
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-Spike failed for DEPH [m]
# QC-Spike failed for PRES_CTD [dbar]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: SCAN_CTD []
# No mapping found for key: SCAN_CTD []
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: PUMP_CTD []
# No mapping found for key: PUMP_CTD []
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-Spike failed for DEPH [m]
# QC-Spike failed for PRES_CTD [dbar]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: SCAN_CTD []
# No mapping found for key: SCAN_CTD []
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: PUMP_CTD []
# No mapping found for key: PUMP_CTD []
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-Spike failed for DEPH [m]
# QC-Spike failed for PRES_CTD [dbar]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: SCAN_CTD []
# No mapping found for key: SCAN_CTD []
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: PUMP_CTD []
# No mapping found for key: PUMP_CTD []
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-Spike failed for DEPH [m]
# QC-Spike failed for PRES_CTD [dbar]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: SCAN_CTD []
# No mapping found for key: SCAN_CTD []
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: PUMP_CTD []
# No mapping found for key: PUMP_CTD []
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-Spike failed for DEPH [m]
# QC-Spike failed for PRES_CTD [dbar]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: SCAN_CTD []
# No mapping found for key: SCAN_CTD []
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: PUMP_CTD []
# No mapping found for key: PUMP_CTD []
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-DataDiff failed for ['SALT_CTD [psu (PSS-78)]', 'SALT2_CTD [psu (PSS-78)]']
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Spike failed for DEPH [m]
# QC-Spike failed for PRES_CTD [dbar]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: SCAN_CTD []
# No mapping found for key: SCAN_CTD []
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: PUMP_CTD []
# No mapping found for key: PUMP_CTD []
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-Spike failed for DEPH [m]
# QC-Spike failed for PRES_CTD [dbar]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: SCAN_CTD []
# No mapping found for key: SCAN_CTD []
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: PUMP_CTD []
# No mapping found for key: PUMP_CTD []
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-Increasing failed for DENS2_CTD [kg/m3]
# QC-Spike failed for DEPH [m]
# QC-Spike failed for PRES_CTD [dbar]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# ...
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: SCAN_CTD []
# No mapping found for key: SCAN_CTD []
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: PUMP_CTD []
# No mapping found for key: PUMP_CTD []
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-Spike failed for DEPH [m]
# QC-Spike failed for PRES_CTD [dbar]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: SCAN_CTD []
# No mapping found for key: SCAN_CTD []
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: PUMP_CTD []
# No mapping found for key: PUMP_CTD []
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-Spike failed for DEPH [m]
# QC-Spike failed for PRES_CTD [dbar]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: SCAN_CTD []
# No mapping found for key: SCAN_CTD []
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: PUMP_CTD []
# No mapping found for key: PUMP_CTD []
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-Spike failed for DEPH [m]
# QC-Spike failed for PRES_CTD [dbar]
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LATITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: LONGITUDE_DD
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q0_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q_DEPH
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q0_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q_PRES_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q0_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q_CNDC_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q0_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q_CNDC2_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q0_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q_SALT_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q0_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q_SALT2_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q0_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q_TEMP_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q0_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q_TEMP2_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q0_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q_DOXY_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q0_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: Q_DOXY2_CTD
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: PAR_CTD [µE/(cm2 sec)]
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q0_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: Q_PAR_CTD
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: CHLFLUO_CTD [mg/m3]
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q0_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: Q_CHLFLUO_CTD
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: TURB_CTD [NTU]
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q0_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: Q_TURB_CTD
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: PHYC_CTD [ppb]
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q0_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: Q_PHYC_CTD
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: ALTM_CTD [m]
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q0_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: Q_ALTM_CTD
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: DESC_RATE_CTD [m/s]
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q0_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: Q_DESC_RATE_CTD
# No mapping found for key: SCAN_CTD []
# No mapping found for key: SCAN_CTD []
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q0_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: Q_SCAN_CTD
# No mapping found for key: PUMP_CTD []
# No mapping found for key: PUMP_CTD []
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q0_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q_PUMP_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q0_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q_DENS_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q0_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: Q_DENS2_CTD
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: SVEL_CTD [m/s]
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q0_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: Q_SVEL_CTD
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: SVEL2_CTD [m/s]
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q0_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# No mapping found for key: Q_SVEL2_CTD
# QC - USER: a002028
# QC-Spike failed for DEPH [m]
# QC-Spike failed for PRES_CTD [dbar]
# QC-Spike failed for TEMP_CTD [°C (ITS-90)]
# QC-Spike failed for TEMP2_CTD [°C (ITS-90)]
# QCBlueprint run--4.328 sec

# %%
first_ds = list(datasets[0])[0]

print('Note format of flagfield')
print(datasets[0][first_ds]['data']['Q0_TEMP_CTD'][:5])

print('\nDataframe from file: {}'.format(first_ds))
datasets[0][first_ds]['data']
# Out:
# Note format of flagfield
# 0    A00AA
# 1    A00AA
# 2    A00AA
# 3    A00AA
# 4    A00AA
# Name: Q0_TEMP_CTD, dtype: object
#
# Dataframe from file: ctd_profile_20200414_77SE_0336.txt
#      YEAR MONTH DAY HOUR MINUTE SECOND                  CRUISE STATION  \
# 0    2020    04  14   11     52     00  2020_77SE_SMHI-07-2020  SLAGGO
# 1    2020    04  14   11     52     00  2020_77SE_SMHI-07-2020  SLAGGO
# 2    2020    04  14   11     52     00  2020_77SE_SMHI-07-2020  SLAGGO
# 3    2020    04  14   11     52     00  2020_77SE_SMHI-07-2020  SLAGGO
# 4    2020    04  14   11     52     00  2020_77SE_SMHI-07-2020  SLAGGO
# ..    ...   ...  ..  ...    ...    ...                     ...     ...
# 138  2020    04  14   11     52     00  2020_77SE_SMHI-07-2020  SLAGGO
# 139  2020    04  14   11     52     00  2020_77SE_SMHI-07-2020  SLAGGO
# 140  2020    04  14   11     52     00  2020_77SE_SMHI-07-2020  SLAGGO
# 141  2020    04  14   11     52     00  2020_77SE_SMHI-07-2020  SLAGGO
# 142  2020    04  14   11     52     00  2020_77SE_SMHI-07-2020  SLAGGO
#
#     LATITUDE_DD LONGITUDE_DD  ... Q_DENS_CTD DENS2_CTD [kg/m3] Q0_DENS2_CTD  \
# 0      58.25983     11.43533  ...                      20.3713        AA0AA
# 1      58.25983     11.43533  ...                      20.3718        AA0AA
# 2      58.25983     11.43533  ...                      20.3706        AA0AA
# 3      58.25983     11.43533  ...                      20.3716        AA0AA
# 4      58.25983     11.43533  ...                      20.3718        AA0AA
# ..          ...          ...  ...        ...               ...          ...
# 138    58.25983     11.43533  ...                      26.5168        AA0AA
# 139    58.25983     11.43533  ...                      26.5132        AA0AA
# 140    58.25983     11.43533  ...                      26.5087        AA0AA
# 141    58.25983     11.43533  ...                      26.5318        AA0AA
# 142    58.25983     11.43533  ...                      26.5480        AA0AA
#
#     Q_DENS2_CTD SVEL_CTD [m/s] Q0_SVEL_CTD Q_SVEL_CTD SVEL2_CTD [m/s]  \
# 0                      1466.32       00000                    1466.33
# 1                      1466.35       00000                    1466.36
# 2                      1466.38       00000                    1466.38
# 3                      1466.40       00000                    1466.39
# 4                      1466.38       00000                    1466.40
# ..          ...            ...         ...        ...             ...
# 138                    1476.31       00000                    1476.31
# 139                    1476.31       00000                    1476.30
# 140                    1476.30       00000                    1476.29
# 141                    1476.35       00000                    1476.39
# 142                    1476.55       00000                    1476.47
#
#     Q0_SVEL2_CTD Q_SVEL2_CTD
# 0          00000        None
# 1          00000        None
# 2          00000        None
# 3          00000        None
# 4          00000        None
# ..           ...         ...
# 138        00000        None
# 139        00000        None
# 140        00000        None
# 141        00000        None
# 142        00000        None
#
# [143 rows x 76 columns]

# %%
#  ##################        UPDATE DATA ACCORDING TO CTD TEMPLATE (TXT-FORMAT)        ###################

# As of now we only export the updated ctd-datafile (ctd-standard-format). 
# delivery_note, metadata, sensorinfo, information are exclude.. (will be included..#TODO..)

start_time = time.time()

data_path = s.save_data(datasets, writer='ctd_standard_template', return_data_path=True)

print("Datasets saved--%.3f sec" % (time.time() - start_time))
# Out:
# Datasets saved--1.074 sec
