# %%
from IPython.core.display import display, HTML
# Increase notebook width to 100%
display(HTML("<style>.container { width:100% !important; }</style>"))

import sys
sys.path.append('C:\\Utveckling\\sharkpylib')
sys.path.append('C:\\Utveckling\\ctdpy')  #  

from ctdpy.core.session import Session
from ctdpy.core.utils import generate_filepaths, get_reversed_dictionary
from ctdpy.core.data_handlers import DataTransformation
from ctdpy.core.writers.profile_plot import QC_WorkTool

import time
from pprint import pprint


from bokeh.io import show, output_notebook

import bokeh
print('bokeh version', bokeh.__version__)
# Out:
# <style>#notebook { padding-top:0px !important; } .container { width:100% !important; } .end_space { min-height:0px !important; } </style>
# bokeh version 1.4.0

# %%
###################        GET FILES        #################### 

base_dir = 'C:\\Utveckling\\ctdpy\\ctdpy\\tests\\etc\\ctd_std_fmt_QC_done_exprapp_april_2020'

files = generate_filepaths(base_dir,
                           endswith='.txt',                # Presumably CTD-standard format
                           only_from_dir=True,
                           )

# %%
###################        Create SESSION object        ###################

s = Session(filepaths=files,
            reader='ctd_stdfmt',
            )

# %%
###################        READ DELIVERY DATA, CNV, XLSX        ###################

start_time = time.time()

datasets = s.read()

print("Datasets loaded--%.3f sec" % (time.time() - start_time))
# Out:
# dataset txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_QC_done_exprapp_april_2020\ctd_profile_20200414_77SE_0336.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_QC_done_exprapp_april_2020\ctd_profile_20200414_77SE_0337.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_QC_done_exprapp_april_2020\ctd_profile_20200414_77SE_0338.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_QC_done_exprapp_april_2020\ctd_profile_20200414_77SE_0339.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_QC_done_exprapp_april_2020\ctd_profile_20200414_77SE_0340.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_QC_done_exprapp_april_2020\ctd_profile_20200414_77SE_0341.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_QC_done_exprapp_april_2020\ctd_profile_20200415_77SE_0342.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_QC_done_exprapp_april_2020\ctd_profile_20200415_77SE_0343.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_QC_done_exprapp_april_2020\ctd_profile_20200415_77SE_0344.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_QC_done_exprapp_april_2020\ctd_profile_20200415_77SE_0345.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_QC_done_exprapp_april_2020\ctd_profile_20200415_77SE_0346.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_QC_done_exprapp_april_2020\ctd_profile_20200416_77SE_0347.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_QC_done_exprapp_april_2020\ctd_profile_20200416_77SE_0348.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_QC_done_exprapp_april_2020\ctd_profile_20200416_77SE_0349.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_QC_done_exprapp_april_2020\ctd_profile_20200416_77SE_0350.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_QC_done_exprapp_april_2020\ctd_profile_20200416_77SE_0351.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_QC_done_exprapp_april_2020\ctd_profile_20200417_77SE_0352.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_QC_done_exprapp_april_2020\ctd_profile_20200417_77SE_0353.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_QC_done_exprapp_april_2020\ctd_profile_20200417_77SE_0354.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_QC_done_exprapp_april_2020\ctd_profile_20200418_77SE_0355.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_QC_done_exprapp_april_2020\ctd_profile_20200418_77SE_0356.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_QC_done_exprapp_april_2020\ctd_profile_20200418_77SE_0357.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_QC_done_exprapp_april_2020\ctd_profile_20200418_77SE_0358.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_QC_done_exprapp_april_2020\ctd_profile_20200419_77SE_0359.txt
# Loading text file: C:\Utveckling\ctdpy\ctdpy\tests\etc\ctd_std_fmt_QC_done_exprapp_april_2020\ctd_profile_20200419_77SE_0360.txt
# Datasets loaded--0.423 sec

# %%
print('Files loaded:')
# pprint(list(datasets[0]))
print('len(datasets):', len(datasets))
# pprint(list(datasets[0]['ctd_profile_20200417_77SE_0353.txt']['data'].columns))
# datasets[0]['ctd_profile_20200417_77SE_0353.txt']['data']['Q_DOXY_CTD']
# datasets[0]['ctd_profile_20200414_77SE_0336.txt']['metadata']
para_list = [p for p in datasets[0]['ctd_profile_20200417_77SE_0353.txt']['data'].columns if ('[' in p and not p.startswith('DEPH') and not p.startswith('PRES'))]
para_list
# Out:
# Files loaded:
# len(datasets): 1
# ['CNDC_CTD [S/m]',
#  'CNDC2_CTD [S/m]',
#  'SALT_CTD [psu (PSS-78)]',
#  'SALT2_CTD [psu (PSS-78)]',
#  'TEMP_CTD [°C (ITS-90)]',
#  'TEMP2_CTD [°C (ITS-90)]',
#  'DOXY_CTD [ml/l]',
#  'DOXY2_CTD [ml/l]',
#  'PAR_CTD [µE/(cm2 sec)]',
#  'CHLFLUO_CTD [mg/m3]',
#  'TURB_CTD [NTU]',
#  'PHYC_CTD [ppb]',
#  'ALTM_CTD [m]',
#  'DESC_RATE_CTD [m/s]',
#  'SCAN_CTD []',
#  'PUMP_CTD []',
#  'DENS_CTD [kg/m3]',
#  'DENS2_CTD [kg/m3]',
#  'SVEL_CTD [m/s]',
#  'SVEL2_CTD [m/s]']

# %%
################      DATA TRANSFORMATION / PREPARATION        ################


## For the moment we have a bug regarding multiple sensors, hence we only plot data from sensor 1.
# para_list = [p for p in datasets[0]['ctd_profile_20200417_77SE_0353.txt']['data'].columns if ('[' in p and not p.startswith('DEPH') and not p.startswith('PRES'))]
# data_parameter_list = []
# for 

# data_parameter_list = ['PRES_CTD [dbar]', 'SALT_CTD [psu (PSS-78)]',
#                        'TEMP_CTD [°C (ITS-90)]', 'DOXY_CTD [ml/l]', ]

data_parameter_list = ['TEMP_CTD [°C (ITS-90)]', 'SALT_CTD [psu (PSS-78)]', 'DOXY_CTD [ml/l]', 'CNDC_CTD [S/m]', 'PAR_CTD [µE/(cm2 sec)]', 'CHLFLUO_CTD [mg/m3]', 'PHYC_CTD [ppb]', 'TURB_CTD [NTU]']
q_flag_parameters = []
auto_q_flag_parameters = []
q_colors = []
q_colors_mapper = {}

plot_parameters_mapping = {'y': 'PRES_CTD [dbar]'}
for i, p in enumerate(data_parameter_list):
    x_key = 'x'+str(i+1)
    q0x_key = x_key+'_q0'
    parameter = p.split()[0]
    c_para = 'color_'+x_key
    q_para = 'Q_'+parameter
    q0_para = 'Q0_'+parameter
    
    q_colors.append(c_para)
    q_flag_parameters.append(q_para)
    auto_q_flag_parameters.append(q0_para)
    
    q_colors_mapper[q0_para] = c_para
    plot_parameters_mapping[x_key] = p
    plot_parameters_mapping[q0x_key] = q0_para

data_parameter_list.append('PRES_CTD [dbar]')
df_parameter_list = data_parameter_list + q_colors + q_flag_parameters + auto_q_flag_parameters + \
                    ['STATION', 'LATITUDE_DD', 'LONGITUDE_DD', 'SDATE', 'MONTH', 'STIME', 'KEY']

parameter_formats = {p: float for p in data_parameter_list}


start_time = time.time()

data_transformer = DataTransformation()
data_transformer.add_keys_to_datasets(datasets)

dataframes = [datasets[0][key].get('data') for key in datasets[0].keys()]
data_transformer.append_dataframes(dataframes)
data_transformer.add_columns()
data_transformer.add_color_columns(auto_q_flag_parameters, mapper=q_colors_mapper)
data_transformer.set_column_format(**parameter_formats)

dataframe = data_transformer.get_dataframe(columns=df_parameter_list)

print("Data retrieved--%.3f sec" % (time.time() - start_time))
# Out:
# appending dataframes..
# dataframes appended!
# Data retrieved--0.362 sec

# %%
############       PLOT (bokeh 1.4)        #############

start_time = time.time()
plot = QCPlot(dataframe,
              datasets[0], 
              parameters=data_parameter_list,
              plot_parameters_mapping=plot_parameters_mapping,
              color_fields=q_colors,
              qflag_fields=q_flag_parameters,
              auto_q_flag_parameters=auto_q_flag_parameters,
#               output_filename="svea_2020.html",                     # Save as html-file (will automatic open in chrome/firefox), only javascript callbacks can be used
              output_as_notebook=True,                              # Open in notebook.. Window size is not ideal for this, BUT! python callbacks works :D
              ctdpy_session=s,
              )
plot.plot_stations()
plot.plot_data()

def bkapp(doc):
    bk_layout = plot.return_layout()
    doc.add_root(bk_layout)
    
show(bkapp)
# print('hej')
# plot.show_plot()
print("Data plotted--%.3f sec" % (time.time() - start_time))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
# Setting up data source structure...
#
# Data source structure completed!
# C:\Utveckling\ctdpy\ctdpy\core\writers\profile_plot.py:1195: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ts_df['x'] = ts_df[self.plot_parameters_mapping.get('x2')]  # x2 = SALT
# C:\Utveckling\ctdpy\ctdpy\core\writers\profile_plot.py:1196: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ts_df['y'] = ts_df[self.plot_parameters_mapping.get('x1')]  # x1 = TEMP
# C:\Utveckling\ctdpy\ctdpy\core\writers\profile_plot.py:1197: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ts_df['color'] = get_color_palette(dep_serie=ts_df[self.plot_parameters_mapping.get('y')])
# <script src="http://localhost:65089/autoload.js?bokeh-autoload-element=1733&bokeh-absolute-url=http://localhost:65089&resources=none" id="1733"></script>
# Data plotted--3.704 sec

# %%
# import numpy as np
# plot.data_source.data

# idx = np.where(~np.isnan(plot.data_source.data['20200414_77SE_0336_PRES_CTD [dbar]']))
# idx = np.where(np.isfinite(plot.data_source.data['20200414_77SE_0336_PRES_CTD [dbar]']))[0]
# print(idx)
# plot.data_source.data['20200414_77SE_0336_Q_DOXY_CTD'][idx]
# plot.datasets['ctd_profile_20200418_77SE_0358.txt']['data'][['DOXY_CTD [ml/l]', 'Q0_DOXY_CTD', 'Q_DOXY_CTD']]
# Out:
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Button(id='1468', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: FileInput(id='1469', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Select(id='1411', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Spacer(id='1747', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Spacer(id='1749', ...)
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Spacer(id='1750', ...)
